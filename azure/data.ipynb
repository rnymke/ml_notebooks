# %%
from azureml.core import Workspace, Datastore


ws = Workspace.from_config()

# %%
for ds_name in ws.datastores:
    print(ds_name)
# Out:
# azureml_globaldatasets
# workspaceblobstore
# workspacefilestore

# %%
# Fetch datastore
blob_store = Datastore.get(workspace = ws, datastore_name = 'workspaceblobstore')
# Upload file to datastore
blob_store.upload_files(files=['data/diabetes.csv'],
                 target_path='diabetes-data-2/',
                 show_progress=True)
# Out:
# Uploading an estimated of 1 files
# Uploading data/diabetes.csv
# Uploaded data/diabetes.csv, 1 files out of an estimated total of 1
# Uploaded 1 files
# $AZUREML_DATAREFERENCE_297c798700ff47d6957e8ca05576de57

# %%
# Download file from datastore
blob_store.download(target_path='downloads/',
                   prefix='diabetes-data-2/')
# Out:
# Downloading diabetes-data-2/diabetes.csv
# Downloaded diabetes-data-2/diabetes.csv, 1 files out of an estimated total of 1
# 1

# %%
# Get reference to uploaded file
ref = blob_store.path('diabetes-data-2').as_download(path_on_compute='path_on_compute')
# This can be passed to script using --data-folder: dataref, 
#--data-ref will simply be the path of the data as it is available in the compute target

# %%
# Create a dataset from the recently uploaded file
from azureml.core import Dataset
tab_ds = Dataset.Tabular.from_delimited_files(path=(blob_store, 'diabetes-data-2/*.csv'))

# %%
# Let's peek
tab_ds.take(5).to_pandas_dataframe()
# Out:
#    PatientID  Pregnancies  PlasmaGlucose  DiastolicBloodPressure  \
# 0    1354778            0            171                      80
# 1    1147438            8             92                      93
# 2    1640031            7            115                      47
# 3    1883350            9            103                      78
# 4    1424119            1             85                      59
#
#    TricepsThickness  SerumInsulin        BMI  DiabetesPedigree  Age  Diabetic
# 0                34            23  43.509726          1.213191   21         0
# 1                47            36  21.240576          0.158365   23         0
# 2                52            35  41.511523          0.079019   23         0
# 3                25           304  29.582192          1.282870   43         1
# 4                27            35  42.604536          0.549542   22         0

# %%
# Register dataset, such that it will be accessible in other contexts
tab_ds.register(workspace=ws, name='diabetes_csv')
# Out:
# {
#   "source": [
#     "('workspaceblobstore', 'diabetes-data-2/*.csv')"
#   ],
#   "definition": [
#     "GetDatastoreFiles",
#     "ParseDelimited",
#     "DropColumns",
#     "SetColumnTypes"
#   ],
#   "registration": {
#     "id": "a21721af-49fc-4a74-887e-31227e1aebf0",
#     "name": "diabetes_csv",
#     "version": 1,
#     "workspace": "Workspace.create(name='ML-2s-sandbox', subscription_id='08265842-251e-450c-8d28-a06ee3f3c611', resource_group='DataSandbox')"
#   }
# }

# %%
# Can access via dataset dict in workspace
ws.datasets['diabetes_csv']
# Out:
# {
#   "source": [
#     "('workspaceblobstore', 'diabetes-data-2/*.csv')"
#   ],
#   "definition": [
#     "GetDatastoreFiles",
#     "ParseDelimited",
#     "DropColumns",
#     "SetColumnTypes"
#   ],
#   "registration": {
#     "id": "a21721af-49fc-4a74-887e-31227e1aebf0",
#     "name": "diabetes_csv",
#     "version": 1,
#     "workspace": "Workspace.create(name='ML-2s-sandbox', subscription_id='08265842-251e-450c-8d28-a06ee3f3c611', resource_group='DataSandbox')"
#   }
# }

# %%
# Get all registered datasets in workspace
Dataset.get_all(ws)
# Out:
# {'diabetes_csv': DatasetRegistration(id='a21721af-49fc-4a74-887e-31227e1aebf0', name='diabetes_csv', version=1, description='', tags={}), 'diabetes target': DatasetRegistration(id='7d97d13c-ad3d-4cd9-bfed-157fba387e76', name='diabetes target', version=1, description='diabetes target data', tags={'format': 'CSV'}), 'diabetes baseline': DatasetRegistration(id='9e4e5917-5885-4e17-84f8-e9623fb74f29', name='diabetes baseline', version=1, description='diabetes baseline data', tags={'format': 'CSV'}), 'diabetes file dataset': DatasetRegistration(id='e3990bf4-01bb-4f72-b2bd-0d80121ec403', name='diabetes file dataset', version=1, description='diabetes files', tags={'format': 'CSV'}), 'diabetes dataset': DatasetRegistration(id='521a535d-8a19-4ccf-bbc4-d89d8c370412', name='diabetes dataset', version=1, description='diabetes data', tags={'format': 'CSV'}), 'penguins': DatasetRegistration(id='f9ed263a-e01b-4114-b17e-9dcc9772c085', name='penguins', version=1, description='', tags={}), 'TD-Auto_Price_Training-Clean_Missing_Data-Cleaning_transformation-42d5a600': DatasetRegistration(id='5df1f375-c5eb-49a0-8f66-6537fa26b7c7', name='TD-Auto_Price_Training-Clean_Missing_Data-Cleaning_transformation-42d5a600', version=1, description='This is a dataset promoted by inference graph generation automatically on 11/16/2020 12:17:18.
#
#  Training pipeline draft:Auto Price Training
#
# Training pipeline draftId:b3f6165c-7060-47f5-b19e-1f1ca643f546
#
# Module Name:Clean Missing Data
#
# ModuleId:55759136-ba28-5d75-b4f7-698369e2198c
#
# Port:Cleaning_transformation', tags={'azureml.Designer': 'true'}), 'TD-Auto_Price_Training-Normalize_Data-Transformation_function-3233b765': DatasetRegistration(id='f52a21c6-a036-4219-9dce-44400fc08a8a', name='TD-Auto_Price_Training-Normalize_Data-Transformation_function-3233b765', version=1, description='This is a dataset promoted by inference graph generation automatically on 11/16/2020 12:17:17.
#
#  Training pipeline draft:Auto Price Training
#
# Training pipeline draftId:b3f6165c-7060-47f5-b19e-1f1ca643f546
#
# Module Name:Normalize Data
#
# ModuleId:911ffb70-e341-5116-9696-7de17bc4d5be
#
# Port:Transformation_function', tags={'azureml.Designer': 'true'}), 'MD-Auto_Price_Training-Train_Model-Trained_model-1d6a60ba': DatasetRegistration(id='fe2a3f38-80a5-4973-a991-4846b53fb336', name='MD-Auto_Price_Training-Train_Model-Trained_model-1d6a60ba', version=1, description='This is a dataset promoted by inference graph generation automatically on 11/16/2020 12:17:15.
#
#  Training pipeline draft:Auto Price Training
#
# Training pipeline draftId:b3f6165c-7060-47f5-b19e-1f1ca643f546
#
# Module Name:Train Model
#
# ModuleId:d9961b0f-36d8-5d0b-91eb-d930a291d498
#
# Port:Trained_model', tags={'azureml.Designer': 'true'}), 'bike-rentals': DatasetRegistration(id='2af1ec0b-4e4d-4f85-b881-ad40412090a7', name='bike-rentals', version=1, description='Bicycle rental data', tags={})}

# %%
# Fetch diabetes_csv by name
Dataset.get_by_name(workspace=ws, name='diabetes_csv')
# Out:
# {
#   "source": [
#     "('workspaceblobstore', 'diabetes-data-2/*.csv')"
#   ],
#   "definition": [
#     "GetDatastoreFiles",
#     "ParseDelimited",
#     "DropColumns",
#     "SetColumnTypes"
#   ],
#   "registration": {
#     "id": "a21721af-49fc-4a74-887e-31227e1aebf0",
#     "name": "diabetes_csv",
#     "version": 1,
#     "workspace": "Workspace.create(name='ML-2s-sandbox', subscription_id='08265842-251e-450c-8d28-a06ee3f3c611', resource_group='DataSandbox')"
#   }
# }

# %%
# Uploading a copy of the file
blob_store.upload_files(files=['data/diabetes.csv'],
                 target_path='diabetes-data-2/diabetes_copy.csv',
                 show_progress=True)
# Out:
# Uploading an estimated of 1 files
# Target already exists. Skipping upload for diabetes-data-2/diabetes_copy.csv\diabetes.csv
# Uploaded 0 files
# $AZUREML_DATAREFERENCE_c868d6f4b1a34a969c9a807a0ffc61ce

# %%
# Creating new version with only the copy of the file of the file
tab_ds = Dataset.Tabular.from_delimited_files(path=(blob_store, 'diabetes-data-2/diabetes_copy.csv'))
tab_ds.register(workspace=ws, name='diabetes_csv', create_new_version=True)
# Out:
# {
#   "source": [
#     "('workspaceblobstore', 'diabetes-data-2/diabetes_copy.csv')"
#   ],
#   "definition": [
#     "GetDatastoreFiles",
#     "ParseDelimited",
#     "DropColumns",
#     "SetColumnTypes"
#   ],
#   "registration": {
#     "id": "6eadd105-1803-48c2-ba8d-cb450cb37604",
#     "name": "diabetes_csv",
#     "version": 3,
#     "workspace": "Workspace.create(name='ML-2s-sandbox', subscription_id='08265842-251e-450c-8d28-a06ee3f3c611', resource_group='DataSandbox')"
#   }
# }

# %%
ds = Dataset.get_by_name(workspace=ws, name='diabetes_csv', version=3)

# %%
df = ds.to_pandas_dataframe()
# Out:
#    PatientID  Pregnancies  PlasmaGlucose  DiastolicBloodPressure  \
# 0    1354778            0            171                      80
# 1    1147438            8             92                      93
# 2    1640031            7            115                      47
# 3    1883350            9            103                      78
# 4    1424119            1             85                      59
#
#    TricepsThickness  SerumInsulin        BMI  DiabetesPedigree  Age  Diabetic
# 0                34            23  43.509726          1.213191   21         0
# 1                47            36  21.240576          0.158365   23         0
# 2                52            35  41.511523          0.079019   23         0
# 3                25           304  29.582192          1.282870   43         1
# 4                27            35  42.604536          0.549542   22         0

# %%
# %%writefile experiment_script/diabetes_experiment_data.py
# Let's create a new script that uses this data, using named input "csv_data"
from azureml.core import Run
import argparse
import pandas as pd
import matplotlib.pyplot as plt
import joblib
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score, plot_confusion_matrix

parser = argparse.ArgumentParser()
parser.add_argument('--reg_rate', type=float, dest='reg', default=0.01)
args = parser.parse_args()
reg = args.reg


# Start logging
run = Run.get_context()

# Input
data = run.input_datasets['csv_data'].to_pandas_dataframe()
X = data.drop(columns=['PatientID', 'Diabetic'])
y = data.iloc[:,-1]

# Scale X
X_scaled = StandardScaler().fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size = 0.2)

# Number of rows in data for funsies
run.log('observations', len(data))
run.log('positives', len(data[data['Diabetic'] == 1]))
run.log('negatives', len(data[data['Diabetic'] == 0]))

# Train a model
model = LogisticRegression(C=1/reg, random_state=0).fit(X_train, y_train)
y_pred = model.predict(X_test)

auc = roc_auc_score(y_test, y_pred)
run.log('AUC', auc)

conf = plot_confusion_matrix(model, X_test, y_test)
run.log_image(name = "confusion_matrix", plot = plt)

# Upload sample file, because why not
sample = data.sample(n=100)
# Creates outputs folder which is auto-uploaded to the experiment, instead of run.upload_file()
sample.to_csv('outputs/sample.csv')
# Save model
joblib.dump(value=model, filename='outputs/model.pkl')

run.complete()
# Out:
# Overwriting experiment_script/diabetes_experiment_data.py

# %%
from azureml.core import Experiment
from azureml.train.estimator import Estimator

estimator = Estimator(source_directory='experiment_script',
                      entry_script='diabetes_experiment_data.py',
                      compute_target='DS-Ass-Cluster',
                      conda_packages=['scikit-learn', 'matplotlib'],
                      script_params = {'--reg_rate': 0.1},
                      inputs=[tab_ds.as_named_input('csv_data')],
                      pip_packages=['azureml-dataprep[pandas]']
                    )
experiment = Experiment(workspace = ws, name='diabetes_experiment_script')
run = experiment.submit(config=estimator)
run.wait_for_completion(show_output=True)
# Out:
# WARNING:root:If 'script' has been provided here and a script file name has been specified in 'run_config', 'script' provided in ScriptRunConfig initialization will take precedence.
# WARNING:root:If 'arguments' has been provided here and arguments have been specified in 'run_config', 'arguments' provided in ScriptRunConfig initialization will take precedence.
# RunId: diabetes_experiment_script_1605791290_91e79e8a
# Web View: https://ml.azure.com/experiments/diabetes_experiment_script/runs/diabetes_experiment_script_1605791290_91e79e8a?wsid=/subscriptions/08265842-251e-450c-8d28-a06ee3f3c611/resourcegroups/DataSandbox/workspaces/ML-2s-sandbox
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
#
# 2020/11/19 13:08:20 Downloading source code...
# 2020/11/19 13:08:21 Finished downloading source code
# 2020/11/19 13:08:22 Creating Docker network: acb_default_network, driver: 'bridge'
# 2020/11/19 13:08:22 Successfully set up Docker network: acb_default_network
# 2020/11/19 13:08:22 Setting up Docker configuration...
# 2020/11/19 13:08:23 Successfully set up Docker configuration
# 2020/11/19 13:08:23 Logging in to registry: 4f065ca9923c4e649f7d27454535e444.azurecr.io
# 2020/11/19 13:08:24 Successfully logged into 4f065ca9923c4e649f7d27454535e444.azurecr.io
# 2020/11/19 13:08:24 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/11/19 13:08:24 Scanning for dependencies...
# 2020/11/19 13:08:25 Successfully scanned dependencies
# 2020/11/19 13:08:25 Launching container with name: acb_step_0
# Sending build context to Docker daemon     64kB
#
# Step 1/14 : FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1@sha256:8cee6f674276dddb23068d2710da7f7f95b119412cc482675ac79ba45a4acf99
# sha256:8cee6f674276dddb23068d2710da7f7f95b119412cc482675ac79ba45a4acf99: Pulling from azureml/intelmpi2018.3-ubuntu16.04
# Digest: sha256:8cee6f674276dddb23068d2710da7f7f95b119412cc482675ac79ba45a4acf99
# Status: Downloaded newer image for mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1@sha256:8cee6f674276dddb23068d2710da7f7f95b119412cc482675ac79ba45a4acf99
#  ---> 287916b809d9
# Step 2/14 : USER root
#  ---> Running in 306958df1c7a
# Removing intermediate container 306958df1c7a
#  ---> 1f966ab28203
# Step 3/14 : RUN mkdir -p $HOME/.cache
#  ---> Running in e192fc942384
# Removing intermediate container e192fc942384
#  ---> f4ed83d92bad
# Step 4/14 : WORKDIR /
#  ---> Running in d06fb4488d7c
# Removing intermediate container d06fb4488d7c
#  ---> 2672211bb93e
# Step 5/14 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> b255e28a1ee1
# Step 6/14 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in efb7f5c5961b
# Removing intermediate container efb7f5c5961b
#  ---> a7ee209cd73d
# Step 7/14 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 336ae04064a8
# Step 8/14 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_a8ca70d65d2e3c18017ee3492bf5c464 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 2f4dcf37aac6
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working...
# done
#
# Downloading and Extracting Packages
#
# icu-58.2             | 22.7 MB   |            |   0%
# icu-58.2             | 22.7 MB   | #1         |  11%
# icu-58.2             | 22.7 MB   | ###7       |  37%
# icu-58.2             | 22.7 MB   | ######1    |  61%
# icu-58.2             | 22.7 MB   | #########4 |  94%
# icu-58.2             | 22.7 MB   | ########## | 100%
#
# freetype-2.10.4      | 901 KB    |            |   0%
# freetype-2.10.4      | 901 KB    | ########## | 100%
#
# pip-20.2.4           | 2.0 MB    |            |   0%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
#
# libuuid-1.0.3        | 16 KB     |            |   0%
# libuuid-1.0.3        | 16 KB     | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# gst-plugins-base-1.1 | 6.3 MB    |            |   0%
# gst-plugins-base-1.1 | 6.3 MB    | ########## | 100%
#
# jpeg-9b              | 247 KB    |            |   0%
# jpeg-9b              | 247 KB    | ########## | 100%
#
# dbus-1.13.18         | 586 KB    |            |   0%
# dbus-1.13.18         | 586 KB    | ########## | 100%
#
# libtiff-4.1.0        | 607 KB    |            |   0%
# libtiff-4.1.0        | 607 KB    | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | ##         |  21%
# python-3.6.2         | 27.0 MB   | ####3      |  44%
# python-3.6.2         | 27.0 MB   | #######    |  71%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# qt-5.9.6             | 86.7 MB   |            |   0%
# qt-5.9.6             | 86.7 MB   | 7          |   7%
# qt-5.9.6             | 86.7 MB   | #6         |  17%
# qt-5.9.6             | 86.7 MB   | ##6        |  26%
# qt-5.9.6             | 86.7 MB   | ###5       |  35%
# qt-5.9.6             | 86.7 MB   | ####4      |  44%
# qt-5.9.6             | 86.7 MB   | #####1     |  52%
# qt-5.9.6             | 86.7 MB   | #####7     |  58%
# qt-5.9.6             | 86.7 MB   | ######6    |  66%
# qt-5.9.6             | 86.7 MB   | #######5   |  76%
# qt-5.9.6             | 86.7 MB   | ########5  |  85%
# qt-5.9.6             | 86.7 MB   | #########3 |  94%
#
# qt-5.9.6             | 86.7 MB   | ########## | 100%
#
# pcre-8.44            | 269 KB    |            |   0%
# pcre-8.44            | 269 KB    | 5          |   6%
# pcre-8.44            | 269 KB    | ########## | 100%
#
# threadpoolctl-2.1.0  | 16 KB     |            |   0%
# threadpoolctl-2.1.0  | 16 KB     | ########## | 100%
#
# tornado-6.0.4        | 650 KB    |            |   0%
# tornado-6.0.4        | 650 KB    | ########## | 100%
#
# kiwisolver-1.2.0     | 91 KB     |            |   0%
# kiwisolver-1.2.0     | 91 KB     | ########## | 100%
#
# scikit-learn-0.23.2  | 6.9 MB    |            |   0%
# scikit-learn-0.23.2  | 6.9 MB    | ####5      |  45%
# scikit-learn-0.23.2  | 6.9 MB    | ########## | 100%
#
# six-1.15.0           | 13 KB     |            |   0%
# six-1.15.0           | 13 KB     | ########## | 100%
#
# numpy-1.19.1         | 20 KB     |            |   0%
# numpy-1.19.1         | 20 KB     | ########## | 100%
#
# numpy-base-1.19.1    | 5.2 MB    |            |   0%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
#
# matplotlib-base-3.3. | 6.7 MB    |            |   0%
# matplotlib-base-3.3. | 6.7 MB    | ######7    |  68%
# matplotlib-base-3.3. | 6.7 MB    | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | ######5    |  66%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
#
# certifi-2020.6.20    | 160 KB    |            |   0%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
#
# sip-4.19.24          | 297 KB    |            |   0%
# sip-4.19.24          | 297 KB    | ########## | 100%
#
# lz4-c-1.9.2          | 203 KB    |            |   0%
# lz4-c-1.9.2          | 203 KB    | ########## | 100%
#
# intel-openmp-2020.2  | 947 KB    |            |   0%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
#
# zstd-1.4.4           | 1006 KB   |            |   0%
# zstd-1.4.4           | 1006 KB   | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# ca-certificates-2020 | 128 KB    |            |   0%
# ca-certificates-2020 | 128 KB    | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
#
# pyqt-5.9.2           | 5.6 MB    |            |   0%
# pyqt-5.9.2           | 5.6 MB    | #######9   |  79%
# pyqt-5.9.2           | 5.6 MB    | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# mkl_random-1.1.0     | 369 KB    |            |   0%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
#
# mkl_fft-1.2.0        | 164 KB    |            |   0%
# mkl_fft-1.2.0        | 164 KB    | ########## | 100%
#
# mkl-2019.4           | 204.1 MB  |            |   0%
# mkl-2019.4           | 204.1 MB  | 2          |   3%
# mkl-2019.4           | 204.1 MB  | 6          |   6%
# mkl-2019.4           | 204.1 MB  | #          |  11%
# mkl-2019.4           | 204.1 MB  | #4         |  14%
# mkl-2019.4           | 204.1 MB  | #6         |  17%
# mkl-2019.4           | 204.1 MB  | ##         |  21%
# mkl-2019.4           | 204.1 MB  | ##3        |  24%
# mkl-2019.4           | 204.1 MB  | ##7        |  28%
# mkl-2019.4           | 204.1 MB  | ###1       |  32%
# mkl-2019.4           | 204.1 MB  | ###5       |  35%
# mkl-2019.4           | 204.1 MB  | ###9       |  39%
# mkl-2019.4           | 204.1 MB  | ####2      |  43%
# mkl-2019.4           | 204.1 MB  | ####6      |  46%
# mkl-2019.4           | 204.1 MB  | #####      |  50%
# mkl-2019.4           | 204.1 MB  | #####4     |  55%
# mkl-2019.4           | 204.1 MB  | #####8     |  58%
# mkl-2019.4           | 204.1 MB  | ######2    |  62%
# mkl-2019.4           | 204.1 MB  | ######6    |  67%
# mkl-2019.4           | 204.1 MB  | #######    |  71%
# mkl-2019.4           | 204.1 MB  | #######4   |  75%
# mkl-2019.4           | 204.1 MB  | #######8   |  79%
# mkl-2019.4           | 204.1 MB  | ########2  |  83%
# mkl-2019.4           | 204.1 MB  | ########6  |  87%
# mkl-2019.4           | 204.1 MB  | #########  |  90%
# mkl-2019.4           | 204.1 MB  | #########4 |  94%
# mkl-2019.4           | 204.1 MB  | #########8 |  99%
#
# mkl-2019.4           | 204.1 MB  | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# wheel-0.35.1         | 36 KB     |            |   0%
# wheel-0.35.1         | 36 KB     | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# gstreamer-1.14.0     | 3.8 MB    |            |   0%
# gstreamer-1.14.0     | 3.8 MB    | ########## | 100%
#
# scipy-1.5.2          | 18.5 MB   |            |   0%
# scipy-1.5.2          | 18.5 MB   | ##5        |  25%
# scipy-1.5.2          | 18.5 MB   | #######    |  70%
# scipy-1.5.2          | 18.5 MB   | ########## | 100%
#
# joblib-0.17.0        | 205 KB    |            |   0%
# joblib-0.17.0        | 205 KB    | ########## | 100%
#
# matplotlib-3.3.1     | 24 KB     |            |   0%
# matplotlib-3.3.1     | 24 KB     | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
#
# expat-2.2.10         | 192 KB    |            |   0%
# expat-2.2.10         | 192 KB    | ########## | 100%
#
# libxcb-1.14          | 610 KB    |            |   0%
# libxcb-1.14          | 610 KB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# glib-2.56.2          | 5.0 MB    |            |   0%
# glib-2.56.2          | 5.0 MB    | ########## | 100%
#
# python-dateutil-2.8. | 224 KB    |            |   0%
# python-dateutil-2.8. | 224 KB    | ########## | 100%
#
# pyparsing-2.4.7      | 64 KB     |            |   0%
# pyparsing-2.4.7      | 64 KB     | ########## | 100%
#
# libxml2-2.9.10       | 1.3 MB    |            |   0%
# libxml2-2.9.10       | 1.3 MB    | ########## | 100%
#
# lcms2-2.11           | 419 KB    |            |   0%
# lcms2-2.11           | 419 KB    | ########## | 100%
#
# libpng-1.6.37        | 364 KB    |            |   0%
# libpng-1.6.37        | 364 KB    | ########## | 100%
#
# fontconfig-2.13.0    | 291 KB    |            |   0%
# fontconfig-2.13.0    | 291 KB    | ########## | 100%
#
# olefile-0.46         | 48 KB     |            |   0%
# olefile-0.46         | 48 KB     | ########## | 100%
#
# cycler-0.10.0        | 13 KB     |            |   0%
# cycler-0.10.0        | 13 KB     | ########## | 100%
#
# mkl-service-2.3.0    | 208 KB    |            |   0%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
#
# setuptools-50.3.0    | 891 KB    |            |   0%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# libffi-3.2.1         | 52 KB     |            |   0%
# libffi-3.2.1         | 52 KB     | ########## | 100%
#
# pillow-8.0.0         | 675 KB    |            |   0%
# pillow-8.0.0         | 675 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_a8ca70d65d2e3c18017ee3492bf5c464/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.uoxh86ho.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.18.0-py3-none-any.whl (3.1 kB)
# Collecting azureml-dataprep[pandas]
#   Downloading azureml_dataprep-2.6.0-py3-none-any.whl (39.4 MB)
# Collecting werkzeug<=1.0.1,>=0.16.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting azureml-core~=1.18.0
#   Downloading azureml_core-1.18.0.post2-py3-none-any.whl (2.1 MB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.18.0
#   Downloading azureml_dataset_runtime-1.18.0-py3-none-any.whl (3.4 kB)
# Collecting azureml-dataprep-rslex<1.5.0a,>=1.4.0dev0
#   Downloading azureml_dataprep_rslex-1.4.0-cp36-cp36m-manylinux2010_x86_64.whl (7.9 MB)
# Collecting azureml-dataprep-native<27.0.0,>=26.0.0
#   Downloading azureml_dataprep_native-26.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.19-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting pyarrow<2.0.0,>=0.17.0; extra == "pandas"
#   Downloading pyarrow-1.0.1-cp36-cp36m-manylinux2014_x86_64.whl (17.3 MB)
# Collecting pandas<2.0.0,>=0.23.4; extra == "pandas"
#   Downloading pandas-1.1.4-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
# Requirement already satisfied, skipping upgrade: numpy<2.0.0,>=1.14.0; extra == "pandas" in /azureml-envs/azureml_a8ca70d65d2e3c18017ee3492bf5c464/lib/python3.6/site-packages (from azureml-dataprep[pandas]->-r /azureml-environment-setup/condaenv.uoxh86ho.requirements.txt (line 2)) (1.19.1)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-2.11.2-py2.py3-none-any.whl (125 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.26.2-py2.py3-none-any.whl (136 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.2.0-py3-none-any.whl (14 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-1.4.1-py2.py3-none-any.whl (36 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.26-py2.py3-none-any.whl (12 kB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.19-py2.py3-none-any.whl (84 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.5-py2.py3-none-any.whl (55 kB)
# Collecting pytz
#   Downloading pytz-2020.4-py2.py3-none-any.whl (509 kB)
# Collecting requests>=2.19.1
#   Downloading requests-2.25.0-py2.py3-none-any.whl (61 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting azure-mgmt-keyvault<7.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting PyJWT<2.0.0
#   Downloading PyJWT-1.7.1-py2.py3-none-any.whl (18 kB)
# Collecting pathspec
#   Downloading pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-10.3.0-py2.py3-none-any.whl (1.0 MB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting ruamel.yaml>=0.15.35
#   Downloading ruamel.yaml-0.16.12-py2.py3-none-any.whl (111 kB)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /azureml-envs/azureml_a8ca70d65d2e3c18017ee3492bf5c464/lib/python3.6/site-packages (from azureml-core~=1.18.0->azureml-defaults->-r /azureml-environment-setup/condaenv.uoxh86ho.requirements.txt (line 1)) (2.8.1)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*
#   Downloading cryptography-3.2.1-cp35-abi3-manylinux2010_x86_64.whl (2.6 MB)
# Collecting pyopenssl<20.0.0
#   Downloading pyOpenSSL-19.1.0-py2.py3-none-any.whl (53 kB)
# Collecting docker
#   Downloading docker-4.3.1-py2.py3-none-any.whl (145 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Requirement already satisfied, skipping upgrade: six>=1.10 in /azureml-envs/azureml_a8ca70d65d2e3c18017ee3492bf5c464/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults->-r /azureml-environment-setup/condaenv.uoxh86ho.requirements.txt (line 1)) (1.15.0)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.3-py2.py3-none-any.whl (81 kB)
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.6.0-py2.py3-none-any.whl (50 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.9.0-py2.py3-none-any.whl (124 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (27 kB)
# Collecting jeepney>=0.4.2
#   Downloading jeepney-0.6.0-py3-none-any.whl (45 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-2.0.0-py2.py3-none-any.whl (31 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_a8ca70d65d2e3c18017ee3492bf5c464/lib/python3.6/site-packages (from msrest>=0.5.1->azureml-core~=1.18.0->azureml-defaults->-r /azureml-environment-setup/condaenv.uoxh86ho.requirements.txt (line 1)) (2020.6.20)
# Collecting chardet<4,>=3.0.2
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9"
#   Downloading ruamel.yaml.clib-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (549 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting cffi!=1.11.3,>=1.8
#   Downloading cffi-1.14.3-cp36-cp36m-manylinux1_x86_64.whl (400 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.57.0-py2.py3-none-any.whl (200 kB)
# Collecting portalocker~=1.0; platform_system != "Windows"
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.0-py3-none-any.whl (5.2 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Building wheels for collected packages: json-logging-py, liac-arff, fusepy
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=053e696c8a47e3a1310ac319aef29d81c94c5bd36460f3c78feb47108ac0feb8
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11730 sha256=2151a5233ff06ad9f1c1dac1b9daaf776a2d16c7ad8afee41cb07f026bd0a46d
#   Stored in directory: /root/.cache/pip/wheels/53/ba/da/8562a6a6dbb428fd1ecc21053106df3948645cd991958f669b
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10504 sha256=e1c7831555a05d0efd1fffa4242441ef4b9b55763c67cc5f152f7f2c3b982569
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
# Successfully built json-logging-py liac-arff fusepy
# Installing collected packages: werkzeug, MarkupSafe, Jinja2, click, itsdangerous, flask, urllib3, pycparser, cffi, cryptography, jeepney, SecretStorage, isodate, chardet, idna, requests, oauthlib, requests-oauthlib, msrest, PyJWT, adal, msrestazure, azure-common, azure-graphrbac, zipp, importlib-metadata, jsonpickle, azure-mgmt-storage, pytz, azure-mgmt-keyvault, pathspec, azure-mgmt-authorization, azure-mgmt-resource, backports.weakref, backports.tempfile, azure-mgmt-containerregistry, ruamel.yaml.clib, ruamel.yaml, pyasn1, pyopenssl, ndg-httpsclient, jmespath, websocket-client, docker, contextlib2, azureml-core, gunicorn, liac-arff, dill, pandas, azureml-model-management-sdk, configparser, applicationinsights, json-logging-py, pyarrow, azureml-dataprep-rslex, azureml-dataprep-native, cloudpickle, msal, azure-core, portalocker, msal-extensions, azure-identity, distro, dotnetcore2, azureml-dataprep, fusepy, azureml-dataset-runtime, azureml-defaults
# Successfully installed Jinja2-2.11.2 MarkupSafe-1.1.1 PyJWT-1.7.1 SecretStorage-3.2.0 adal-1.2.5 applicationinsights-0.11.9 azure-common-1.1.26 azure-core-1.9.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-10.3.0 azure-mgmt-storage-11.2.0 azureml-core-1.18.0.post2 azureml-dataprep-2.6.0 azureml-dataprep-native-26.0.0 azureml-dataprep-rslex-1.4.0 azureml-dataset-runtime-1.18.0 azureml-defaults-1.18.0 azureml-model-management-sdk-1.0.1b6.post1 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.3 chardet-3.0.4 click-7.1.2 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-3.2.1 dill-0.3.3 distro-1.5.0 docker-4.3.1 dotnetcore2-2.1.19 flask-1.0.3 fusepy-3.0.1 gunicorn-19.9.0 idna-2.10 importlib-metadata-2.0.0 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.6.0 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-1.4.1 liac-arff-2.5.0 msal-1.6.0 msal-extensions-0.2.2 msrest-0.6.19 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.1.0 pandas-1.1.4 pathspec-0.8.1 portalocker-1.7.1 pyarrow-1.0.1 pyasn1-0.4.8 pycparser-2.20 pyopenssl-19.1.0 pytz-2020.4 requests-2.25.0 requests-oauthlib-1.3.0 ruamel.yaml-0.16.12 ruamel.yaml.clib-0.2.2 urllib3-1.26.2 websocket-client-0.57.0 werkzeug-1.0.1 zipp-3.4.0
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_a8ca70d65d2e3c18017ee3492bf5c464
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 2f4dcf37aac6
#  ---> bebeb6530c74
# Step 9/14 : ENV PATH /azureml-envs/azureml_a8ca70d65d2e3c18017ee3492bf5c464/bin:$PATH
#  ---> Running in eb36a49737db
# Removing intermediate container eb36a49737db
#  ---> 0931f1b9d754
# Step 10/14 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_a8ca70d65d2e3c18017ee3492bf5c464
#  ---> Running in 82475a73e578
# Removing intermediate container 82475a73e578
#  ---> 75e7a878b9f9
# Step 11/14 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_a8ca70d65d2e3c18017ee3492bf5c464/lib:$LD_LIBRARY_PATH
#  ---> Running in 310611045dd9
# Removing intermediate container 310611045dd9
#  ---> 37a1d3acf336
# Step 12/14 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 862c8a025a09
# Step 13/14 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 391157177e3f
# Removing intermediate container 391157177e3f
#  ---> 435577149ebc
# Step 14/14 : CMD ["bash"]
#  ---> Running in 09f255ee5bc8
# Removing intermediate container 09f255ee5bc8
#  ---> 1169884f8556
# Successfully built 1169884f8556
# Successfully tagged 4f065ca9923c4e649f7d27454535e444.azurecr.io/azureml/azureml_43e9380a32931235e3e4e9c47d2444a4:latest
# 2020/11/19 13:13:04 Successfully executed container: acb_step_0
# 2020/11/19 13:13:04 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2020/11/19 13:13:04 Pushing image: 4f065ca9923c4e649f7d27454535e444.azurecr.io/azureml/azureml_43e9380a32931235e3e4e9c47d2444a4:latest, attempt 1
# The push refers to repository [4f065ca9923c4e649f7d27454535e444.azurecr.io/azureml/azureml_43e9380a32931235e3e4e9c47d2444a4]
# 8ed08cdb79a7: Preparing
# d4ac0afa599c: Preparing
# 7cd31e20e78d: Preparing
# 99a2f83696c9: Preparing
# 560f2d6dbfaa: Preparing
# 8eb705bcd14e: Preparing
# 13e378616f24: Preparing
# efc99d952c3d: Preparing
# 9e292a80b88a: Preparing
# 5e1805eb9eb5: Preparing
# 8dab94e6d05c: Preparing
# 2817caf0a082: Preparing
# aece08fd27fc: Preparing
# 4caea5ef1f0b: Preparing
# dcc0cc99372e: Preparing
# 87c128261339: Preparing
# 41a253a417e6: Preparing
# e06660e80cf4: Preparing
# 8dab94e6d05c: Waiting
# 2817caf0a082: Waiting
# aece08fd27fc: Waiting
# 4caea5ef1f0b: Waiting
# dcc0cc99372e: Waiting
# 87c128261339: Waiting
# 41a253a417e6: Waiting
# e06660e80cf4: Waiting
# efc99d952c3d: Waiting
# 9e292a80b88a: Waiting
# 5e1805eb9eb5: Waiting
# 8eb705bcd14e: Waiting
# 13e378616f24: Waiting
# 8ed08cdb79a7: Pushed
# 560f2d6dbfaa: Pushed
# 99a2f83696c9: Pushed
# 7cd31e20e78d: Pushed
# 8eb705bcd14e: Pushed
# 13e378616f24: Pushed
# efc99d952c3d: Pushed
# 9e292a80b88a: Pushed
# aece08fd27fc: Pushed
# 2817caf0a082: Pushed
# dcc0cc99372e: Pushed
# 8dab94e6d05c: Pushed
# 5e1805eb9eb5: Pushed
# 41a253a417e6: Pushed
# 87c128261339: Pushed
# 4caea5ef1f0b: Pushed
# e06660e80cf4: Pushed
#
# Streaming azureml-logs/55_azureml-execution-tvmps_45e2fdfa077002afd6cc669d2e60345d2437a15b3f6f7804468b531330c26210_d.txt
# ========================================================================================================================
#
# 2020-11-19T13:16:32Z Starting output-watcher...
# 2020-11-19T13:16:32Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2020-11-19T13:16:33Z Executing 'Copy ACR Details file' on 10.0.0.7
# 2020-11-19T13:16:33Z Copy ACR Details file succeeded on 10.0.0.7. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_43e9380a32931235e3e4e9c47d2444a4
# 8e097b52bfb8: Already exists
# a613a9b4553c: Already exists
# acc000f01536: Already exists
# 73eef93b7466: Already exists
# d5a54c1fb97f: Already exists
# 1536f6ca931b: Already exists
# d7b631d130cb: Already exists
# 75ffe8dfb222: Already exists
# 86b4bf2f8d5f: Already exists
# 5335952fa8d3: Already exists
# 96fa3cc6fe10: Already exists
# e428dd9daa94: Already exists
# 7e6c961df8a8: Pulling fs layer
# 0bbca9fc466c: Pulling fs layer
# b3ac022cd713: Pulling fs layer
# 7660f58cb7fa: Pulling fs layer
# fe61fa1b13e8: Pulling fs layer
# 305f19772885: Pulling fs layer
# 7660f58cb7fa: Waiting
# fe61fa1b13e8: Waiting
# 305f19772885: Waiting
# 7e6c961df8a8: Verifying Checksum
# 7e6c961df8a8: Download complete
# b3ac022cd713: Verifying Checksum
# b3ac022cd713: Download complete
# 7e6c961df8a8: Pull complete
# 7660f58cb7fa: Verifying Checksum
# 7660f58cb7fa: Download complete
# 305f19772885: Verifying Checksum
# 305f19772885: Download complete
# 0bbca9fc466c: Verifying Checksum
# 0bbca9fc466c: Download complete
# 0bbca9fc466c: Pull complete
# b3ac022cd713: Pull complete
# 7660f58cb7fa: Pull complete
# fe61fa1b13e8: Verifying Checksum
# fe61fa1b13e8: Download complete
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
#
# 2020/11/19 13:17:49 Attempt 1 of http call to http://10.0.0.7:16384/sendlogstoartifacts/info
# 2020/11/19 13:17:49 Attempt 1 of http call to http://10.0.0.7:16384/sendlogstoartifacts/status
# [2020-11-19T13:17:50.747025] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['diabetes_experiment_data.py', '--reg_rate', '0.1'])
# Script type = None
# Starting the daemon thread to refresh tokens in background for process with pid = 101
# Entering Run History Context Manager.
# Current directory:  /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/diabetes_experiment_script_1605791290_91e79e8a/mounts/workspaceblobstore/azureml/diabetes_experiment_script_1605791290_91e79e8a
# Preparing to call script [ diabetes_experiment_data.py ] with arguments: ['--reg_rate', '0.1']
# After variable expansion, calling script [ diabetes_experiment_data.py ] with arguments: ['--reg_rate', '0.1']
#
#
# Streaming azureml-logs/75_job_post-tvmps_45e2fdfa077002afd6cc669d2e60345d2437a15b3f6f7804468b531330c26210_d.txt
# ===============================================================================================================
#
# [2020-11-19T13:18:22.741069] Entering job release
# [2020-11-19T13:18:23.821473] Starting job release
# [2020-11-19T13:18:23.822358] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 330
# [2020-11-19T13:18:23.831591] job release stage : upload_datastore starting...
# [2020-11-19T13:18:23.831889] job release stage : start importing azureml.history._tracking in run_history_release.
# [2020-11-19T13:18:23.831985] job release stage : execute_job_release starting...
# [2020-11-19T13:18:23.832655] job release stage : copy_batchai_cached_logs starting...
# [2020-11-19T13:18:23.832932] job release stage : copy_batchai_cached_logs completed...
# [2020-11-19T13:18:23.833750] Entering context manager injector.
# [2020-11-19T13:18:23.835239] job release stage : upload_datastore completed...
# [2020-11-19T13:18:24.096371] job release stage : send_run_telemetry starting...
# [2020-11-19T13:18:24.240599] job release stage : execute_job_release completed...
# [2020-11-19T13:18:25.150349] job release stage : send_run_telemetry completed...
# [2020-11-19T13:18:25.150640] Job release is complete
#
# Execution Summary
# =================
# RunId: diabetes_experiment_script_1605791290_91e79e8a
# Web View: https://ml.azure.com/experiments/diabetes_experiment_script/runs/diabetes_experiment_script_1605791290_91e79e8a?wsid=/subscriptions/08265842-251e-450c-8d28-a06ee3f3c611/resourcegroups/DataSandbox/workspaces/ML-2s-sandbox
# {'runId': 'diabetes_experiment_script_1605791290_91e79e8a',
#  'target': 'DS-Ass-Cluster',
#  'status': 'Completed',
#  'startTimeUtc': '2020-11-19T13:16:30.610074Z',
#  'endTimeUtc': '2020-11-19T13:18:33.714534Z',
#  'properties': {'_azureml.ComputeTargetType': 'amlcompute',
#   'ContentSnapshotId': 'f4d5acc7-cc96-4958-b863-56dab9bcb5a6',
#   'azureml.git.repository_uri': 'https://github.com/rnymke/ml_notebooks.git',
#   'mlflow.source.git.repoURL': 'https://github.com/rnymke/ml_notebooks.git',
#   'azureml.git.branch': 'master',
#   'mlflow.source.git.branch': 'master',
#   'azureml.git.commit': '8af96ae52bd6c42d317ab31b4d725835ec37e29b',
#   'mlflow.source.git.commit': '8af96ae52bd6c42d317ab31b4d725835ec37e29b',
#   'azureml.git.dirty': 'True',
#   'ProcessInfoFile': 'azureml-logs/process_info.json',
#   'ProcessStatusFile': 'azureml-logs/process_status.json'},
#  'inputDatasets': [{'dataset': {'id': '6eadd105-1803-48c2-ba8d-cb450cb37604'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'csv_data', 'mechanism': 'Direct'}}],
#  'outputDatasets': [],
#  'runDefinition': {'script': 'diabetes_experiment_data.py',
#   'useAbsolutePath': False,
#   'arguments': ['--reg_rate', '0.1'],
#   'sourceDirectoryDataStore': None,
#   'framework': 'Python',
#   'communicator': 'None',
#   'target': 'DS-Ass-Cluster',
#   'dataReferences': {},
#   'data': {'csv_data': {'dataLocation': {'dataset': {'id': '6eadd105-1803-48c2-ba8d-cb450cb37604',
#       'name': None,
#       'version': None},
#      'dataPath': None},
#     'mechanism': 'Direct',
#     'environmentVariableName': 'csv_data',
#     'pathOnCompute': None,
#     'overwrite': False}},
#   'outputData': {},
#   'jobName': None,
#   'maxRunDurationSeconds': None,
#   'nodeCount': 1,
#   'priority': None,
#   'environment': {'name': 'Experiment diabetes_experiment_script Environment',
#    'version': 'Autosave_2020-11-19T13:08:15Z_17b3c060',
#    'python': {'interpreterPath': 'python',
#     'userManagedDependencies': False,
#     'condaDependencies': {'channels': ['anaconda', 'conda-forge'],
#      'dependencies': ['python=3.6.2',
#       {'pip': ['azureml-defaults', 'azureml-dataprep[pandas]']},
#       'scikit-learn',
#       'matplotlib'],
#      'name': 'azureml_a8ca70d65d2e3c18017ee3492bf5c464'},
#     'baseCondaEnvironment': None},
#    'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'},
#    'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1',
#     'platform': {'os': 'Linux', 'architecture': 'amd64'},
#     'baseDockerfile': None,
#     'baseImageRegistry': {'address': None, 'username': None, 'password': None},
#     'enabled': True,
#     'arguments': []},
#    'spark': {'repositories': [], 'packages': [], 'precachePackages': False},
#    'inferencingStackVersion': None},
#   'history': {'outputCollection': True,
#    'directoriesToWatch': ['logs'],
#    'enableMLflowTracking': True,
#    'snapshotProject': True},
#   'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment',
#     'spark.yarn.maxAppAttempts': '1'}},
#   'parallelTask': {'maxRetriesPerWorker': 0,
#    'workerCountPerNode': 1,
#    'terminalExitCodes': None,
#    'configuration': {}},
#   'amlCompute': {'name': None,
#    'vmSize': None,
#    'retainCluster': False,
#    'clusterMaxNodeCount': 1},
#   'aiSuperComputer': {'instanceType': None,
#    'frameworkImage': None,
#    'imageVersion': None,
#    'location': None},
#   'tensorflow': {'workerCount': 1, 'parameterServerCount': 1},
#   'mpi': {'processCountPerNode': 1},
#   'hdi': {'yarnDeployMode': 'Cluster'},
#   'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5},
#   'exposedPorts': None,
#   'docker': {'useDocker': True,
#    'sharedVolumes': True,
#    'shmSize': '2g',
#    'arguments': []},
#   'cmk8sCompute': {'configuration': {}}},
#  'logFiles': {'azureml-logs/20_image_build_log.txt': 'https://ml2ssandbox5194139173.blob.core.windows.net/azureml/ExperimentRun/dcid.diabetes_experiment_script_1605791290_91e79e8a/azureml-logs/20_image_build_log.txt?sv=2019-02-02&sr=b&sig=yW50wwOq8kixlCRrUmLOYGyz%2FWPXTuu8SxAjaA0FqWY%3D&st=2020-11-19T13%3A09%3A15Z&se=2020-11-19T21%3A19%3A15Z&sp=r',
#   'azureml-logs/55_azureml-execution-tvmps_45e2fdfa077002afd6cc669d2e60345d2437a15b3f6f7804468b531330c26210_d.txt': 'https://ml2ssandbox5194139173.blob.core.windows.net/azureml/ExperimentRun/dcid.diabetes_experiment_script_1605791290_91e79e8a/azureml-logs/55_azureml-execution-tvmps_45e2fdfa077002afd6cc669d2e60345d2437a15b3f6f7804468b531330c26210_d.txt?sv=2019-02-02&sr=b&sig=d1LDPTsAAiAOQLz%2FGSsEB19%2FXkJQtLDkmVH66r9QKvI%3D&st=2020-11-19T13%3A09%3A15Z&se=2020-11-19T21%3A19%3A15Z&sp=r',
#   'azureml-logs/65_job_prep-tvmps_45e2fdfa077002afd6cc669d2e60345d2437a15b3f6f7804468b531330c26210_d.txt': 'https://ml2ssandbox5194139173.blob.core.windows.net/azureml/ExperimentRun/dcid.diabetes_experiment_script_1605791290_91e79e8a/azureml-logs/65_job_prep-tvmps_45e2fdfa077002afd6cc669d2e60345d2437a15b3f6f7804468b531330c26210_d.txt?sv=2019-02-02&sr=b&sig=S8SPQSQQ%2FXqzuKHjRzmWt4xhNC0uxF6RnBJVtTLYxhQ%3D&st=2020-11-19T13%3A09%3A15Z&se=2020-11-19T21%3A19%3A15Z&sp=r',
#   'azureml-logs/70_driver_log.txt': 'https://ml2ssandbox5194139173.blob.core.windows.net/azureml/ExperimentRun/dcid.diabetes_experiment_script_1605791290_91e79e8a/azureml-logs/70_driver_log.txt?sv=2019-02-02&sr=b&sig=c14SD%2BRHTxQ7tDzW2YPspplVZ3v6l0olR3dWlN5CkmM%3D&st=2020-11-19T13%3A09%3A15Z&se=2020-11-19T21%3A19%3A15Z&sp=r',
#   'azureml-logs/75_job_post-tvmps_45e2fdfa077002afd6cc669d2e60345d2437a15b3f6f7804468b531330c26210_d.txt': 'https://ml2ssandbox5194139173.blob.core.windows.net/azureml/ExperimentRun/dcid.diabetes_experiment_script_1605791290_91e79e8a/azureml-logs/75_job_post-tvmps_45e2fdfa077002afd6cc669d2e60345d2437a15b3f6f7804468b531330c26210_d.txt?sv=2019-02-02&sr=b&sig=NBEWn3BtYI%2FMdZEhgUmsHW14ECwKwCi6%2FPqKp%2FK4EYU%3D&st=2020-11-19T13%3A09%3A15Z&se=2020-11-19T21%3A19%3A15Z&sp=r',
#   'azureml-logs/process_info.json': 'https://ml2ssandbox5194139173.blob.core.windows.net/azureml/ExperimentRun/dcid.diabetes_experiment_script_1605791290_91e79e8a/azureml-logs/process_info.json?sv=2019-02-02&sr=b&sig=Kg3xJOzTFd3OLIMftkNq%2BfRqPp0BzXmG5caLkeXr52g%3D&st=2020-11-19T13%3A09%3A15Z&se=2020-11-19T21%3A19%3A15Z&sp=r',
#   'azureml-logs/process_status.json': 'https://ml2ssandbox5194139173.blob.core.windows.net/azureml/ExperimentRun/dcid.diabetes_experiment_script_1605791290_91e79e8a/azureml-logs/process_status.json?sv=2019-02-02&sr=b&sig=AbJFQKmj5gmskKTl%2FXL6GhCzcTtqXbb8th7ZvX4JioU%3D&st=2020-11-19T13%3A09%3A15Z&se=2020-11-19T21%3A19%3A15Z&sp=r',
#   'logs/azureml/101_azureml.log': 'https://ml2ssandbox5194139173.blob.core.windows.net/azureml/ExperimentRun/dcid.diabetes_experiment_script_1605791290_91e79e8a/logs/azureml/101_azureml.log?sv=2019-02-02&sr=b&sig=I58YVlpLUzW7%2Fhl8q54de%2F8qaQKVEIe1rk%2BfZShP2%2Fg%3D&st=2020-11-19T13%3A09%3A15Z&se=2020-11-19T21%3A19%3A15Z&sp=r',
#   'logs/azureml/dataprep/backgroundProcess.log': 'https://ml2ssandbox5194139173.blob.core.windows.net/azureml/ExperimentRun/dcid.diabetes_experiment_script_1605791290_91e79e8a/logs/azureml/dataprep/backgroundProcess.log?sv=2019-02-02&sr=b&sig=S9SeZnV6a%2BEcKqf7Kzx1Rg68wzRJVdigCK79DSg1zCg%3D&st=2020-11-19T13%3A09%3A15Z&se=2020-11-19T21%3A19%3A15Z&sp=r',
#   'logs/azureml/dataprep/backgroundProcess_Telemetry.log': 'https://ml2ssandbox5194139173.blob.core.windows.net/azureml/ExperimentRun/dcid.diabetes_experiment_script_1605791290_91e79e8a/logs/azureml/dataprep/backgroundProcess_Telemetry.log?sv=2019-02-02&sr=b&sig=8PzhvPF%2BwPazVaUzYwsJTzvHckHi4X0YHN6du6%2B8ccQ%3D&st=2020-11-19T13%3A09%3A15Z&se=2020-11-19T21%3A19%3A15Z&sp=r',
#   'logs/azureml/dataprep/engine_spans_l_36b8661c-e9da-48ee-8c66-bbf57cdc2c69.jsonl': 'https://ml2ssandbox5194139173.blob.core.windows.net/azureml/ExperimentRun/dcid.diabetes_experiment_script_1605791290_91e79e8a/logs/azureml/dataprep/engine_spans_l_36b8661c-e9da-48ee-8c66-bbf57cdc2c69.jsonl?sv=2019-02-02&sr=b&sig=DkWjTzX4f9O%2Bx9xgw1PK3FUJ1H02bZ9zO3nMZko35zc%3D&st=2020-11-19T13%3A09%3A15Z&se=2020-11-19T21%3A19%3A15Z&sp=r',
#   'logs/azureml/dataprep/python_span_l_36b8661c-e9da-48ee-8c66-bbf57cdc2c69.jsonl': 'https://ml2ssandbox5194139173.blob.core.windows.net/azureml/ExperimentRun/dcid.diabetes_experiment_script_1605791290_91e79e8a/logs/azureml/dataprep/python_span_l_36b8661c-e9da-48ee-8c66-bbf57cdc2c69.jsonl?sv=2019-02-02&sr=b&sig=JEoGjHZ%2BxSW%2FqBUX6XY4VTLelmXVI%2FJCM2NIDlWVT1I%3D&st=2020-11-19T13%3A09%3A15Z&se=2020-11-19T21%3A19%3A15Z&sp=r',
#   'logs/azureml/job_prep_azureml.log': 'https://ml2ssandbox5194139173.blob.core.windows.net/azureml/ExperimentRun/dcid.diabetes_experiment_script_1605791290_91e79e8a/logs/azureml/job_prep_azureml.log?sv=2019-02-02&sr=b&sig=R6wpqBQP0IOubl5IbCYMoCNvxCLJ1OxT6BPjftCDCvI%3D&st=2020-11-19T13%3A09%3A15Z&se=2020-11-19T21%3A19%3A15Z&sp=r',
#   'logs/azureml/job_release_azureml.log': 'https://ml2ssandbox5194139173.blob.core.windows.net/azureml/ExperimentRun/dcid.diabetes_experiment_script_1605791290_91e79e8a/logs/azureml/job_release_azureml.log?sv=2019-02-02&sr=b&sig=k74zMlPMdYmjATodPlmqfCP%2Bfl%2Bf%2FAKYqMxYKYpmZHE%3D&st=2020-11-19T13%3A09%3A15Z&se=2020-11-19T21%3A19%3A15Z&sp=r'}}

# %%
run.get_metrics()
# Out:
# {'observations': 15000,
#  'positives': 5000,
#  'negatives': 10000,
#  'AUC': 0.7304744988835704,
#  'confusion_matrix': 'aml://artifactId/ExperimentRun/dcid.diabetes_experiment_script_1605791290_91e79e8a/confusion_matrix_1605791890.png'}
