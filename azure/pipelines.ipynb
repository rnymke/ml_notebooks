# %%
from azureml.core import Workspace, Datastore, Dataset

ws = Workspace.from_config()

# %%
ds_def = Datastore.get_default(ws) # Get workspace blob store

# %%
ds_def.upload_files(files=['data/diabetes.csv'],
                   target_path='dia-data/',
                   show_progress=True)
# Out:
# Uploading an estimated of 1 files
# Target already exists. Skipping upload for dia-data/diabetes.csv
# Uploaded 0 files
# $AZUREML_DATAREFERENCE_e510e4d414344af4b117032480f3cdf1

# %%
tab_ds = Dataset.Tabular.from_delimited_files(path=(ds_def, 'dia-data/diabetes.csv'))

# %%
tab_ds.register(workspace=ws, 
                name='diab_dataset',
                description='diabetes data',
                tags = {'format':'CSV'},
                create_new_version=True)
# Out:
# {
#   "source": [
#     "('workspaceblobstore', 'dia-data/diabetes.csv')"
#   ],
#   "definition": [
#     "GetDatastoreFiles",
#     "ParseDelimited",
#     "DropColumns",
#     "SetColumnTypes"
#   ],
#   "registration": {
#     "id": "c6830310-2400-40f1-8578-1cd942f89e34",
#     "name": "diab_dataset",
#     "version": 1,
#     "description": "diabetes data",
#     "tags": {
#       "format": "CSV"
#     },
#     "workspace": "Workspace.create(name='ML-2s-sandbox', subscription_id='08265842-251e-450c-8d28-a06ee3f3c611', resource_group='DataSandbox')"
#   }
# }

# %%
from azureml.pipeline.core import PipelineData
from azureml.pipeline.steps import PythonScriptStep, EstimatorStep
from azureml.train.estimator import Estimator
from azureml.core.runconfig import RunConfiguration

# Output folder name
compute_target = 'DS-Ass-Cluster'

# Define data preparation PipelineData object
prepped_data = PipelineData(name='prepped_data', datastore=ws.get_default_datastore())

model_pipe = PipelineData(name='model', datastore=ws.get_default_datastore())

# Define estimator
estimator = Estimator(source_directory='pipeline_script',
                      entry_script='preprocess_data.py',
                      compute_target=compute_target,
                      conda_packages=['scikit-learn', 'matplotlib'],
                      pip_packages=['azureml-dataprep[pandas]'])

estimator2 = Estimator(source_directory='pipeline_script',
                      entry_script='diabetes_experiment.py',
                      compute_target=compute_target,
                      conda_packages=['scikit-learn', 'matplotlib'],
                      pip_packages=['azureml-dataprep[pandas]'])




# First step, prepares data by preprocessing it (just removed a column here), then outputs
# the prepared data to output folder
step1 = EstimatorStep(name='prep data', 
                     estimator=estimator,
                     compute_target=compute_target,
                     inputs=[tab_ds.as_named_input('raw_data')],
                     outputs=[prepped_data],
                     estimator_entry_script_arguments=['--output-folder', prepped_data])

# Second step, reads the data and train a model
step2 = EstimatorStep(name='train model',
                     estimator=estimator2,
                     compute_target=compute_target,
                     inputs=[prepped_data],
                     estimator_entry_script_arguments=['--input-folder', prepped_data])

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline

pipe_steps = [step1, step2]
pipe = Pipeline(workspace=ws, steps=pipe_steps)

experiment = Experiment(workspace = ws, name = 'diabetes-test-pipeline')
pipeline_run = experiment.submit(pipe, regenerate_outputs=True)
print("Pipeline submitted for execution.")
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Created step prep data [26eb2e10][50af0a44-acf7-435e-8c28-d5c356a8def3], (This step will run and generate new outputs)
# Created step train model [c7b16640][fec89449-8b51-4478-93a7-dca54c311451], (This step will run and generate new outputs)
# Submitted PipelineRun 3ff91f37-a11d-4d57-a9c5-df44797d7b90
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/diabetes-test-pipeline/runs/3ff91f37-a11d-4d57-a9c5-df44797d7b90?wsid=/subscriptions/08265842-251e-450c-8d28-a06ee3f3c611/resourcegroups/DataSandbox/workspaces/ML-2s-sandbox
# Pipeline submitted for execution.
# PipelineRunId: 3ff91f37-a11d-4d57-a9c5-df44797d7b90
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/diabetes-test-pipeline/runs/3ff91f37-a11d-4d57-a9c5-df44797d7b90?wsid=/subscriptions/08265842-251e-450c-8d28-a06ee3f3c611/resourcegroups/DataSandbox/workspaces/ML-2s-sandbox
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: f9a75782-f51a-43c1-a237-b5bb3c504167
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/diabetes-test-pipeline/runs/f9a75782-f51a-43c1-a237-b5bb3c504167?wsid=/subscriptions/08265842-251e-450c-8d28-a06ee3f3c611/resourcegroups/DataSandbox/workspaces/ML-2s-sandbox
# StepRun( prep data ) Status: NotStarted
#
# Streaming azureml-logs/55_azureml-execution-tvmps_bb32c84b0f6820ee92ce0bad528bd58853b1776800a68b6091f7d3b1f951f533_d.txt
# ========================================================================================================================
# 2020-11-19T15:34:02Z Starting output-watcher...
# 2020-11-19T15:34:02Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2020-11-19T15:34:03Z Executing 'Copy ACR Details file' on 10.0.0.8
# StepRun( prep data ) Status: Running
# 2020-11-19T15:34:03Z Copy ACR Details file succeeded on 10.0.0.8. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_43e9380a32931235e3e4e9c47d2444a4
# Digest: sha256:a4da65591e6541d4dba22a5cf835c9e56d6707ff37fb933581ea9ae46c695719
# Status: Image is up to date for 4f065ca9923c4e649f7d27454535e444.azurecr.io/azureml/azureml_43e9380a32931235e3e4e9c47d2444a4:latest
# 4f065ca9923c4e649f7d27454535e444.azurecr.io/azureml/azureml_43e9380a32931235e3e4e9c47d2444a4:latest
# 2020-11-19T15:34:04Z Check if container f9a75782-f51a-43c1-a237-b5bb3c504167 already exist exited with 0,
#
# 7662b5b34eb118ffc75deab6cbc314fea7a8fba5a3f2466dfd007d2615e687d5
# 2020/11/19 15:34:05 Starting App Insight Logger for task:  containerSetup
# 2020/11/19 15:34:05 Version: 3.0.01405.0001 Branch: .SourceBranch Commit: a9557e7
# 2020/11/19 15:34:05 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2020/11/19 15:34:05 sshd inside container not required for job, skipping setup.
# 2020/11/19 15:34:05 All App Insights Logs was send successfully
# 2020-11-19T15:34:05Z Starting docker container succeeded.
# 2020-11-19T15:34:11Z Job environment preparation succeeded on 10.0.0.8. Output:
# >>>   2020/11/19 15:33:59 Starting App Insight Logger for task:  prepareJobEnvironment
# >>>   2020/11/19 15:33:59 Version: 3.0.01405.0001 Branch: .SourceBranch Commit: a9557e7
# >>>   2020/11/19 15:33:59 runtime.GOOS linux
# >>>   2020/11/19 15:33:59 Reading dyanamic configs
# >>>   2020/11/19 15:33:59 Container sas url: https://baiscriptsdb3prod.blob.core.windows.net/aihosttools?sv=2018-03-28&sr=c&si=aihosttoolspolicy&sig=C5qYa8w7DcGiMMSKT2OPCw8bl0hKB9umyusoqUwMb%2Bk%3D
# >>>   2020/11/19 15:33:59 Failed to read from file /mnt/batch/tasks/startup/wd/az_resource/xdsenv.variable/azsecpack.variables, open /mnt/batch/tasks/startup/wd/az_resource/xdsenv.variable/azsecpack.variables: no such file or directory
# >>>   2020/11/19 15:33:59 [in autoUpgradeFromJobNodeSetup] Is Azsecpack installed false, isEnable false,
# >>>   2020/11/19 15:33:59 azsecpack isEnable:false,GetDisableVsatlsscan:true
# >>>   2020/11/19 15:33:59 [doTurnOffAzsecpack] output:   Active: inactive (dead)
# >>>   ,err:<nil>.
# >>>   2020/11/19 15:33:59 OS patching disabled by dynamic configs. Skipping.
# >>>   2020/11/19 15:33:59 DetonationChamber is not enabled on this subscription: 08265842-251e-450c-8d28-a06ee3f3c611
# >>>   2020/11/19 15:33:59 GPU count found: 0
# >>>   2020/11/19 15:33:59 AMLComputeXDSEndpoint:  https://db3-prodk8ds.batchai.core.windows.net
# >>>   2020/11/19 15:33:59 AMLComputeXDSApiVersion:  2018-02-01
# >>>   2020/11/19 15:33:59 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/config
# >>>   2020/11/19 15:33:59 This is not a aml-workstation (compute instance), current offer type: azureml. Starting identity responder as part of prepareJobEnvironment.
# >>>   2020/11/19 15:33:59 Starting identity responder.
# >>>   2020/11/19 15:33:59 Starting identity responder.
# >>>   2020/11/19 15:33:59 Failed to open file /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/config/.batchai.IdentityResponder.envlist: open /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/config/.batchai.IdentityResponder.envlist: no such file or directory
# >>>   2020/11/19 15:33:59 Logfile used for identity responder: /mnt/batch/tasks/workitems/960825bc-8db4-4430-90bb-c72061b50f37/job-1/f9a75782-f51a-43c1-a_bd2d7b96-9bac-4c50-934a-a8e92c511c8e/IdentityResponderLog-tvmps_bb32c84b0f6820ee92ce0bad528bd58853b1776800a68b6091f7d3b1f951f533_d.txt
# >>>   2020/11/19 15:33:59 Logfile used for identity responder: /mnt/batch/tasks/workitems/960825bc-8db4-4430-90bb-c72061b50f37/job-1/f9a75782-f51a-43c1-a_bd2d7b96-9bac-4c50-934a-a8e92c511c8e/IdentityResponderLog-tvmps_bb32c84b0f6820ee92ce0bad528bd58853b1776800a68b6091f7d3b1f951f533_d.txt
# >>>   2020/11/19 15:33:59 Started Identity Responder for job.
# >>>   2020/11/19 15:33:59 Started Identity Responder for job.
# >>>   2020/11/19 15:33:59 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/wd
# >>>   2020/11/19 15:33:59 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/shared
# >>>   2020/11/19 15:33:59 Mounting job level file systems
# >>>   2020/11/19 15:33:59 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/mounts
# >>>   2020/11/19 15:33:59 Attempting to read datastore credentials file: /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/config/.amlcompute.datastorecredentials
# >>>   2020/11/19 15:33:59 Datastore credentials file not found, skipping.
# >>>   2020/11/19 15:33:59 Attempting to read runtime sas tokens file: /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/config/.master.runtimesastokens
# >>>   2020/11/19 15:33:59 Runtime sas tokens file not found, skipping.
# >>>   2020/11/19 15:33:59 No NFS configured
# >>>   2020/11/19 15:33:59 No Azure File Shares configured
# >>>   2020/11/19 15:33:59 Mounting blob file systems
# >>>   2020/11/19 15:33:59 Blobfuse runtime version blobfuse 1.3.5
# >>>   2020/11/19 15:33:59 Mounting azureml-blobstore-4f065ca9-923c-4e64-9f7d-27454535e444 container from ml2ssandbox5194139173 account at /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/mounts/workspaceblobstore
# >>>   2020/11/19 15:33:59 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2020/11/19 15:33:59 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2020/11/19 15:33:59 Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/caches/workspaceblobstore --file-cache-timeout-in-seconds=1000000 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# >>>   2020/11/19 15:34:00 Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/mounts/workspaceblobstore
# >>>   2020/11/19 15:34:00 Waiting for blobfs to be mounted at /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/mounts/workspaceblobstore
# >>>   2020/11/19 15:34:00 Successfully mounted azureml-blobstore-4f065ca9-923c-4e64-9f7d-27454535e444 container from ml2ssandbox5194139173 account at /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/mounts/workspaceblobstore
# >>>   2020/11/19 15:34:00 No unmanaged file systems configured
# >>>   2020/11/19 15:34:00 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/mounts/workspaceblobstore/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/azureml_compute_logs
# >>>   2020/11/19 15:34:01 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/mounts/workspaceblobstore/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/logs
# >>>   2020/11/19 15:34:02 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/mounts/workspaceblobstore/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/outputs
# >>>   2020/11/19 15:34:02 Starting output-watcher...
# >>>   2020/11/19 15:34:02 Single file input dataset is enabled.
# >>>   2020/11/19 15:34:02 Start to pulling docker image: 4f065ca9923c4e649f7d27454535e444.azurecr.io/azureml/azureml_43e9380a32931235e3e4e9c47d2444a4
# >>>   2020/11/19 15:34:02 Start pull docker image: 4f065ca9923c4e649f7d27454535e444.azurecr.io
# >>>   2020/11/19 15:34:02 Getting ACR Credentials from EMS for environment Experiment diabetes-test-pipeline Environment:Autosave_2020-11-19T15:18:21Z_9cd0bbc6
# >>>   2020/11/19 15:34:02 Requesting XDS for registry details.
# >>>   2020/11/19 15:34:02 Attempt 1 of http call to https://db3-prodk8ds.batchai.core.windows.net/hosttoolapi/subscriptions/08265842-251e-450c-8d28-a06ee3f3c611/resourceGroups/datasandbox/workspaces/ml-2s-sandbox/clusters/ds-ass-cluster/nodes/tvmps_bb32c84b0f6820ee92ce0bad528bd58853b1776800a68b6091f7d3b1f951f533_d?api-version=2018-02-01
# >>>   2020/11/19 15:34:03 Attempt 1. XDS Api returned non-successful ErrorCode: Success
# >>>    ErrorMessage:
# >>>
# >>>   2020/11/19 15:34:03 Got container registry details from credentials service for registry address: 4f065ca9923c4e649f7d27454535e444.azurecr.io.
# >>>   2020/11/19 15:34:03 Writing ACR Details to file...
# >>>   2020/11/19 15:34:03 Copying ACR Details file to worker nodes...
# >>>   2020/11/19 15:34:03 Executing 'Copy ACR Details file' on 10.0.0.8
# >>>   2020/11/19 15:34:03 Copy ACR Details file succeeded on 10.0.0.8. Output:
# >>>   >>>
# >>>   >>>
# >>>   2020/11/19 15:34:03 Successfully retrieved ACR Credentials from EMS.
# >>>   2020/11/19 15:34:03 EMS returned 4f065ca9923c4e649f7d27454535e444.azurecr.io for environment Experiment diabetes-test-pipeline Environment
# >>>   2020/11/19 15:34:03 Container registry is ACR.
# >>>   2020/11/19 15:34:03 start login to the docker registry
# >>>   2020/11/19 15:34:03 Successfully logged into the docker registry.
# >>>   2020/11/19 15:34:03 Start run pull docker image command
# >>>   2020/11/19 15:34:04 Pull docker image succeeded.
# >>>   2020/11/19 15:34:04 Pull docker image time: 1.346960485s
# >>>
# >>>   2020/11/19 15:34:04 Docker Version that this nodes use are: 19.03.13+azure
# >>>
# >>>   2020/11/19 15:34:04 The env variable file size is 36492 bytes
# >>>   2020/11/19 15:34:04 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# >>>   2020/11/19 15:34:04 Running Docker command: docker run --ulimit memlock=9223372036854775807 --ulimit nofile=262144:262144 --cap-add sys_ptrace --name f9a75782-f51a-43c1-a237-b5bb3c504167 -v /mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts -v /mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs -v /mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared -v /mnt/batch/tasks/workitems/960825bc-8db4-4430-90bb-c72061b50f37/job-1/f9a75782-f51a-43c1-a_bd2d7b96-9bac-4c50-934a-a8e92c511c8e/certs:/mnt/batch/tasks/workitems/960825bc-8db4-4430-90bb-c72061b50f37/job-1/f9a75782-f51a-43c1-a_bd2d7b96-9bac-4c50-934a-a8e92c511c8e/certs -v /mnt/batch/tasks/startup:/mnt/batch/tasks/startup -v /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/mounts/workspaceblobstore/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/azureml_compute_logs:/mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/mounts/workspaceblobstore/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/azureml_compute_logs -v /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167:/mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167 -v /mnt/batch/tasks/workitems/960825bc-8db4-4430-90bb-c72061b50f37/job-1/f9a75782-f51a-43c1-a_bd2d7b96-9bac-4c50-934a-a8e92c511c8e/wd:/mnt/batch/tasks/workitems/960825bc-8db4-4430-90bb-c72061b50f37/job-1/f9a75782-f51a-43c1-a_bd2d7b96-9bac-4c50-934a-a8e92c511c8e/wd -v /opt/azureml:/opt/azureml:ro -w /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/wd --expose 23 --env-file /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/config/.batchai.envlist --shm-size 2g -d -it --privileged --net=host 4f065ca9923c4e649f7d27454535e444.azurecr.io/azureml/azureml_43e9380a32931235e3e4e9c47d2444a4
# >>>   2020/11/19 15:34:04 Check if container f9a75782-f51a-43c1-a237-b5bb3c504167 already exist exited with 0,
# >>>
# >>>   2020/11/19 15:34:04 Check if container f9a75782-f51a-43c1-a237-b5bb3c504167 already exist exited with 0,
# >>>
# >>>   2020/11/19 15:34:04 Attempt 1 of http call to https://northeurope.experiments.azureml.net/history/v1.0/private/subscriptions/08265842-251e-450c-8d28-a06ee3f3c611/resourceGroups/DataSandbox/providers/Microsoft.MachineLearningServices/workspaces/ML-2s-sandbox/runs/f9a75782-f51a-43c1-a237-b5bb3c504167/spans
# >>>   2020/11/19 15:34:05 Container ssh is not required for job type.
# >>>   2020/11/19 15:34:05 Starting docker container succeeded.
# >>>   2020/11/19 15:34:05 Starting docker container succeeded.
# >>>   2020/11/19 15:34:06 runSpecialJobTask: os.GetEnv constants.StdouterrDir: /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/mounts/workspaceblobstore/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/azureml_compute_logs
# >>>   2020/11/19 15:34:06 runSpecialJobTask: Raw cmd for preparation is passed is: /azureml-envs/azureml_a8ca70d65d2e3c18017ee3492bf5c464/bin/python /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/mounts/workspaceblobstore/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"a5e3e774-0434-4491-b848-1debdf6413c3","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2020/11/19 15:34:06 runSpecialJobTask: stdout path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/mounts/workspaceblobstore/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/azureml_compute_logs/65_job_prep-tvmps_bb32c84b0f6820ee92ce0bad528bd58853b1776800a68b6091f7d3b1f951f533_d.txt
# >>>   2020/11/19 15:34:06 runSpecialJobTask: stderr path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/mounts/workspaceblobstore/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/azureml_compute_logs/65_job_prep-tvmps_bb32c84b0f6820ee92ce0bad528bd58853b1776800a68b6091f7d3b1f951f533_d.txt
# >>>   2020/11/19 15:34:06 native cmd: cd /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/mounts/workspaceblobstore/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167;/azureml-envs/azureml_a8ca70d65d2e3c18017ee3492bf5c464/bin/python /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/mounts/workspaceblobstore/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"a5e3e774-0434-4491-b848-1debdf6413c3","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2020/11/19 15:34:06 runSpecialJobTask: commons.GetOsPlatform(): ubuntu
# >>>   2020/11/19 15:34:06 runSpecialJobTask: Running cmd: /usr/bin/docker exec -t f9a75782-f51a-43c1-a237-b5bb3c504167 bash -c if [ -f ~/.bashrc ]; then PS1_back=$PS1; PS1='$'; . ~/.bashrc; PS1=$PS1_back; fi;PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;cd /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/mounts/workspaceblobstore/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167;/azureml-envs/azureml_a8ca70d65d2e3c18017ee3492bf5c464/bin/python /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/mounts/workspaceblobstore/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"a5e3e774-0434-4491-b848-1debdf6413c3","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2020/11/19 15:34:11 runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2020/11/19 15:34:11 runSpecialJobTask: preparation: [2020-11-19T15:34:07.419296] Entering job preparation.
# >>>   2020/11/19 15:34:11 runSpecialJobTask: preparation: [2020-11-19T15:34:08.066765] Starting job preparation.
# >>>   2020/11/19 15:34:11 runSpecialJobTask: preparation: [2020-11-19T15:34:08.066805] Extracting the control code.
# >>>   2020/11/19 15:34:11 runSpecialJobTask: preparation: [2020-11-19T15:34:08.087956] fetching and extracting the control code on master node.
# >>>   2020/11/19 15:34:11 runSpecialJobTask: preparation: [2020-11-19T15:34:08.088003] Starting extract_project.
# >>>   2020/11/19 15:34:11 runSpecialJobTask: preparation: [2020-11-19T15:34:08.088048] Starting to extract zip file.
# >>>   2020/11/19 15:34:11 runSpecialJobTask: preparation: [2020-11-19T15:34:08.897353] Finished extracting zip file.
# >>>   2020/11/19 15:34:11 runSpecialJobTask: preparation: [2020-11-19T15:34:09.095180] Using urllib.request Python 3.0 or later
# >>>   2020/11/19 15:34:11 runSpecialJobTask: preparation: [2020-11-19T15:34:09.095257] Start fetching snapshots.
# >>>   2020/11/19 15:34:11 runSpecialJobTask: preparation: [2020-11-19T15:34:09.095333] Start fetching snapshot.
# >>>   2020/11/19 15:34:11 runSpecialJobTask: preparation: [2020-11-19T15:34:09.095354] Retrieving project from snapshot: a5e3e774-0434-4491-b848-1debdf6413c3
# >>>   2020/11/19 15:34:11 runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 48
# >>>   2020/11/19 15:34:11 runSpecialJobTask: preparation: [2020-11-19T15:34:09.613119] Finished fetching snapshot.
# >>>   2020/11/19 15:34:11 runSpecialJobTask: preparation: [2020-11-19T15:34:09.613160] Finished fetching snapshots.
# >>>   2020/11/19 15:34:11 runSpecialJobTask: preparation: [2020-11-19T15:34:09.613182] Finished extract_project.
# >>>   2020/11/19 15:34:11 runSpecialJobTask: preparation: [2020-11-19T15:34:09.625648] Finished fetching and extracting the control code.
# >>>   2020/11/19 15:34:11 runSpecialJobTask: preparation: [2020-11-19T15:34:09.628351] downloadDataStore - Download from datastores if requested.
# >>>   2020/11/19 15:34:11 runSpecialJobTask: preparation: [2020-11-19T15:34:09.629549] Start run_history_prep.
# >>>   2020/11/19 15:34:11 runSpecialJobTask: preparation: [2020-11-19T15:34:09.712106] Entering context manager injector.
# >>>   2020/11/19 15:34:11 runSpecialJobTask: preparation: Acquired lockfile /tmp/f9a75782-f51a-43c1-a237-b5bb3c504167-datastore.lock to downloading input data references
# >>>   2020/11/19 15:34:11 runSpecialJobTask: preparation: [2020-11-19T15:34:11.124086] downloadDataStore completed
# >>>   2020/11/19 15:34:11 runSpecialJobTask: preparation: [2020-11-19T15:34:11.127479] Job preparation is complete.
# >>>   2020/11/19 15:34:11 All App Insights Logs was send successfully
# >>>   2020/11/19 15:34:11 Process Exiting with Code:  0
# >>>
# 2020-11-19T15:34:11Z 127.0.0.1 slots=2 max-slots=2
# 2020-11-19T15:34:11Z launching Custom job
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2020/11/19 15:34:11 Attempt 1 of http call to http://10.0.0.8:16384/sendlogstoartifacts/info
# 2020/11/19 15:34:11 Attempt 1 of http call to http://10.0.0.8:16384/sendlogstoartifacts/status
# [2020-11-19T15:34:13.471783] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['preprocess_data.py', '--output-folder', '/mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/mounts/workspaceblobstore/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/prepped_data'])
# Script type = None
# Starting the daemon thread to refresh tokens in background for process with pid = 101
# Entering Run History Context Manager.
# Current directory:  /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/mounts/workspaceblobstore/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167
# Preparing to call script [ preprocess_data.py ] with arguments: ['--output-folder', '/mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/mounts/workspaceblobstore/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/prepped_data']
# After variable expansion, calling script [ preprocess_data.py ] with arguments: ['--output-folder', '/mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/mounts/workspaceblobstore/azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/prepped_data']
#
# Starting the daemon thread to refresh tokens in background for process with pid = 101
#
#
# [2020-11-19T15:34:29.902330] The experiment completed successfully. Finalizing run...
# Cleaning up all outstanding Run operations, waiting 900.0 seconds
# 2 items cleaning up...
# Cleanup took 0.3035092353820801 seconds
# [2020-11-19T15:34:31.207893] Finished context manager injector.
# 2020/11/19 15:34:35 Attempt 1 of http call to http://10.0.0.8:16384/sendlogstoartifacts/status
# 2020/11/19 15:34:35 Process Exiting with Code:  0
#
# Streaming azureml-logs/75_job_post-tvmps_bb32c84b0f6820ee92ce0bad528bd58853b1776800a68b6091f7d3b1f951f533_d.txt
# ===============================================================================================================
# [2020-11-19T15:34:36.118090] Entering job release
# [2020-11-19T15:34:37.207263] Starting job release
# [2020-11-19T15:34:37.208177] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 329
# [2020-11-19T15:34:37.210559] job release stage : upload_datastore starting...
# [2020-11-19T15:34:37.217679] job release stage : start importing azureml.history._tracking in run_history_release.
# [2020-11-19T15:34:37.218115] job release stage : execute_job_release starting...
# [2020-11-19T15:34:37.218940] job release stage : copy_batchai_cached_logs starting...
# [2020-11-19T15:34:37.219360] job release stage : copy_batchai_cached_logs completed...
# [2020-11-19T15:34:37.219868] Entering context manager injector.
# [2020-11-19T15:34:37.427657] job release stage : upload_datastore completed...
# [2020-11-19T15:34:37.485875] job release stage : send_run_telemetry starting...
# [2020-11-19T15:34:37.641032] job release stage : execute_job_release completed...
# [2020-11-19T15:34:39.097605] job release stage : send_run_telemetry completed...
# [2020-11-19T15:34:39.098052] Job release is complete
#
# StepRun(prep data) Execution Summary
# =====================================
# StepRun( prep data ) Status: Finished
# {'runId': 'f9a75782-f51a-43c1-a237-b5bb3c504167', 'target': 'DS-Ass-Cluster', 'status': 'Completed', 'startTimeUtc': '2020-11-19T15:34:02.547159Z', 'endTimeUtc': '2020-11-19T15:34:45.925794Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': 'a5e3e774-0434-4491-b848-1debdf6413c3', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '50af0a44-acf7-435e-8c28-d5c356a8def3', 'azureml.nodeid': '26eb2e10', 'azureml.pipelinerunid': '3ff91f37-a11d-4d57-a9c5-df44797d7b90', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [{'dataset': {'id': 'c6830310-2400-40f1-8578-1cd942f89e34'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'raw_data', 'mechanism': 'Direct'}}], 'outputDatasets': [], 'runDefinition': {'script': 'preprocess_data.py', 'useAbsolutePath': False, 'arguments': ['--output-folder', '$AZUREML_DATAREFERENCE_prepped_data'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'DS-Ass-Cluster', 'dataReferences': {'prepped_data': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/prepped_data', 'pathOnCompute': None, 'overwrite': False}}, 'data': {'raw_data': {'dataLocation': {'dataset': {'id': 'c6830310-2400-40f1-8578-1cd942f89e34', 'name': None, 'version': None}, 'dataPath': None}, 'mechanism': 'Direct', 'environmentVariableName': 'raw_data', 'pathOnCompute': None, 'overwrite': False}}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'environment': {'name': 'Experiment diabetes-test-pipeline Environment', 'version': 'Autosave_2020-11-19T15:18:21Z_9cd0bbc6', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults', 'azureml-dataprep[pandas]']}, 'scikit-learn', 'matplotlib'], 'name': 'azureml_a8ca70d65d2e3c18017ee3492bf5c464'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': False}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'frameworkImage': None, 'imageVersion': None, 'location': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_bb32c84b0f6820ee92ce0bad528bd58853b1776800a68b6091f7d3b1f951f533_d.txt': 'https://ml2ssandbox5194139173.blob.core.windows.net/azureml/ExperimentRun/dcid.f9a75782-f51a-43c1-a237-b5bb3c504167/azureml-logs/55_azureml-execution-tvmps_bb32c84b0f6820ee92ce0bad528bd58853b1776800a68b6091f7d3b1f951f533_d.txt?sv=2019-02-02&sr=b&sig=6AljATOJCR3iY%2FxpzwoXByPKHgQD%2B0duWghjUQNOQVE%3D&st=2020-11-19T15%3A24%3A41Z&se=2 ...
#
#
#
#
# StepRunId: 3c5f5207-50d3-48df-ae55-c47ad2ab36ea
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/diabetes-test-pipeline/runs/3c5f5207-50d3-48df-ae55-c47ad2ab36ea?wsid=/subscriptions/08265842-251e-450c-8d28-a06ee3f3c611/resourcegroups/DataSandbox/workspaces/ML-2s-sandbox
# StepRun( train model ) Status: NotStarted
# StepRun( train model ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_bb32c84b0f6820ee92ce0bad528bd58853b1776800a68b6091f7d3b1f951f533_d.txt
# ========================================================================================================================
# 2020-11-19T15:35:14Z Starting output-watcher...
# 2020-11-19T15:35:14Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2020-11-19T15:35:15Z Executing 'Copy ACR Details file' on 10.0.0.8
# 2020-11-19T15:35:15Z Copy ACR Details file succeeded on 10.0.0.8. Output:
# >>>
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_43e9380a32931235e3e4e9c47d2444a4
# Digest: sha256:a4da65591e6541d4dba22a5cf835c9e56d6707ff37fb933581ea9ae46c695719
# Status: Image is up to date for 4f065ca9923c4e649f7d27454535e444.azurecr.io/azureml/azureml_43e9380a32931235e3e4e9c47d2444a4:latest
# 4f065ca9923c4e649f7d27454535e444.azurecr.io/azureml/azureml_43e9380a32931235e3e4e9c47d2444a4:latest
# 2020-11-19T15:35:16Z Check if container 3c5f5207-50d3-48df-ae55-c47ad2ab36ea already exist exited with 0,
#
# ab45b26b466f16508b0c2e8f4e08eaeedce8afa4e9575f957b5619d140120cd8
# 2020/11/19 15:35:17 Starting App Insight Logger for task:  containerSetup
# 2020/11/19 15:35:17 Version: 3.0.01405.0001 Branch: .SourceBranch Commit: a9557e7
# 2020/11/19 15:35:17 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2020/11/19 15:35:17 sshd inside container not required for job, skipping setup.
# 2020/11/19 15:35:17 All App Insights Logs was send successfully
# 2020-11-19T15:35:17Z Starting docker container succeeded.
# 2020-11-19T15:35:23Z Job environment preparation succeeded on 10.0.0.8. Output:
# >>>   2020/11/19 15:35:11 Starting App Insight Logger for task:  prepareJobEnvironment
# >>>   2020/11/19 15:35:11 Version: 3.0.01405.0001 Branch: .SourceBranch Commit: a9557e7
# >>>   2020/11/19 15:35:11 runtime.GOOS linux
# >>>   2020/11/19 15:35:11 Reading dyanamic configs
# >>>   2020/11/19 15:35:11 Container sas url: https://baiscriptsdb3prod.blob.core.windows.net/aihosttools?sv=2018-03-28&sr=c&si=aihosttoolspolicy&sig=C5qYa8w7DcGiMMSKT2OPCw8bl0hKB9umyusoqUwMb%2Bk%3D
# >>>   2020/11/19 15:35:11 Failed to read from file /mnt/batch/tasks/startup/wd/az_resource/xdsenv.variable/azsecpack.variables, open /mnt/batch/tasks/startup/wd/az_resource/xdsenv.variable/azsecpack.variables: no such file or directory
# >>>   2020/11/19 15:35:11 [in autoUpgradeFromJobNodeSetup] Is Azsecpack installed false, isEnable false,
# >>>   2020/11/19 15:35:11 azsecpack isEnable:false,GetDisableVsatlsscan:true
# >>>   2020/11/19 15:35:11 [doTurnOffAzsecpack] output:   Active: inactive (dead)
# >>>   ,err:<nil>.
# >>>   2020/11/19 15:35:11 OS patching disabled by dynamic configs. Skipping.
# >>>   2020/11/19 15:35:11 DetonationChamber is not enabled on this subscription: 08265842-251e-450c-8d28-a06ee3f3c611
# >>>   2020/11/19 15:35:11 GPU count found: 0
# >>>   2020/11/19 15:35:11 AMLComputeXDSEndpoint:  https://db3-prodk8ds.batchai.core.windows.net
# >>>   2020/11/19 15:35:11 AMLComputeXDSApiVersion:  2018-02-01
# >>>   2020/11/19 15:35:11 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/config
# >>>   2020/11/19 15:35:11 This is not a aml-workstation (compute instance), current offer type: azureml. Starting identity responder as part of prepareJobEnvironment.
# >>>   2020/11/19 15:35:11 Starting identity responder.
# >>>   2020/11/19 15:35:11 Starting identity responder.
# >>>   2020/11/19 15:35:11 Failed to open file /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/config/.batchai.IdentityResponder.envlist: open /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/config/.batchai.IdentityResponder.envlist: no such file or directory
# >>>   2020/11/19 15:35:11 Logfile used for identity responder: /mnt/batch/tasks/workitems/960825bc-8db4-4430-90bb-c72061b50f37/job-1/3c5f5207-50d3-48df-a_710580c2-ea34-4781-b477-d4913e28463f/IdentityResponderLog-tvmps_bb32c84b0f6820ee92ce0bad528bd58853b1776800a68b6091f7d3b1f951f533_d.txt
# >>>   2020/11/19 15:35:11 Logfile used for identity responder: /mnt/batch/tasks/workitems/960825bc-8db4-4430-90bb-c72061b50f37/job-1/3c5f5207-50d3-48df-a_710580c2-ea34-4781-b477-d4913e28463f/IdentityResponderLog-tvmps_bb32c84b0f6820ee92ce0bad528bd58853b1776800a68b6091f7d3b1f951f533_d.txt
# >>>   2020/11/19 15:35:11 Started Identity Responder for job.
# >>>   2020/11/19 15:35:11 Started Identity Responder for job.
# >>>   2020/11/19 15:35:11 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/wd
# >>>   2020/11/19 15:35:11 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/shared
# >>>   2020/11/19 15:35:11 Mounting job level file systems
# >>>   2020/11/19 15:35:11 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/mounts
# >>>   2020/11/19 15:35:11 Attempting to read datastore credentials file: /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/config/.amlcompute.datastorecredentials
# >>>   2020/11/19 15:35:11 Datastore credentials file not found, skipping.
# >>>   2020/11/19 15:35:11 Attempting to read runtime sas tokens file: /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/config/.master.runtimesastokens
# >>>   2020/11/19 15:35:11 Runtime sas tokens file not found, skipping.
# >>>   2020/11/19 15:35:11 No NFS configured
# >>>   2020/11/19 15:35:11 No Azure File Shares configured
# >>>   2020/11/19 15:35:11 Mounting blob file systems
# >>>   2020/11/19 15:35:11 Blobfuse runtime version blobfuse 1.3.5
# >>>   2020/11/19 15:35:11 Mounting azureml-blobstore-4f065ca9-923c-4e64-9f7d-27454535e444 container from ml2ssandbox5194139173 account at /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/mounts/workspaceblobstore
# >>>   2020/11/19 15:35:11 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2020/11/19 15:35:11 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2020/11/19 15:35:11 Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/caches/workspaceblobstore --file-cache-timeout-in-seconds=1000000 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# >>>   2020/11/19 15:35:12 Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/mounts/workspaceblobstore
# >>>   2020/11/19 15:35:12 Waiting for blobfs to be mounted at /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/mounts/workspaceblobstore
# >>>   2020/11/19 15:35:12 Successfully mounted azureml-blobstore-4f065ca9-923c-4e64-9f7d-27454535e444 container from ml2ssandbox5194139173 account at /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/mounts/workspaceblobstore
# >>>   2020/11/19 15:35:12 No unmanaged file systems configured
# >>>   2020/11/19 15:35:12 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/mounts/workspaceblobstore/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/azureml_compute_logs
# >>>   2020/11/19 15:35:13 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/mounts/workspaceblobstore/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/logs
# >>>   2020/11/19 15:35:14 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/mounts/workspaceblobstore/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/outputs
# >>>   2020/11/19 15:35:14 Starting output-watcher...
# >>>   2020/11/19 15:35:14 Single file input dataset is enabled.
# >>>   2020/11/19 15:35:14 Start to pulling docker image: 4f065ca9923c4e649f7d27454535e444.azurecr.io/azureml/azureml_43e9380a32931235e3e4e9c47d2444a4
# >>>   2020/11/19 15:35:14 Start pull docker image: 4f065ca9923c4e649f7d27454535e444.azurecr.io
# >>>   2020/11/19 15:35:14 Getting ACR Credentials from EMS for environment Experiment diabetes-test-pipeline Environment:Autosave_2020-11-19T15:18:21Z_9cd0bbc6
# >>>   2020/11/19 15:35:14 Requesting XDS for registry details.
# >>>   2020/11/19 15:35:14 Attempt 1 of http call to https://db3-prodk8ds.batchai.core.windows.net/hosttoolapi/subscriptions/08265842-251e-450c-8d28-a06ee3f3c611/resourceGroups/datasandbox/workspaces/ml-2s-sandbox/clusters/ds-ass-cluster/nodes/tvmps_bb32c84b0f6820ee92ce0bad528bd58853b1776800a68b6091f7d3b1f951f533_d?api-version=2018-02-01
# >>>   2020/11/19 15:35:15 Attempt 1. XDS Api returned non-successful ErrorCode: Success
# >>>    ErrorMessage:
# >>>
# >>>   2020/11/19 15:35:15 Got container registry details from credentials service for registry address: 4f065ca9923c4e649f7d27454535e444.azurecr.io.
# >>>   2020/11/19 15:35:15 Writing ACR Details to file...
# >>>   2020/11/19 15:35:15 Copying ACR Details file to worker nodes...
# >>>   2020/11/19 15:35:15 Executing 'Copy ACR Details file' on 10.0.0.8
# >>>   2020/11/19 15:35:15 Copy ACR Details file succeeded on 10.0.0.8. Output:
# >>>   >>>
# >>>   >>>
# >>>   2020/11/19 15:35:15 Successfully retrieved ACR Credentials from EMS.
# >>>   2020/11/19 15:35:15 EMS returned 4f065ca9923c4e649f7d27454535e444.azurecr.io for environment Experiment diabetes-test-pipeline Environment
# >>>   2020/11/19 15:35:15 Container registry is ACR.
# >>>   2020/11/19 15:35:15 start login to the docker registry
# >>>   2020/11/19 15:35:15 Successfully logged into the docker registry.
# >>>   2020/11/19 15:35:15 Start run pull docker image command
# >>>   2020/11/19 15:35:15 Pull docker image succeeded.
# >>>   2020/11/19 15:35:15 Pull docker image time: 1.076205044s
# >>>
# >>>   2020/11/19 15:35:15 Docker Version that this nodes use are: 19.03.13+azure
# >>>
# >>>   2020/11/19 15:35:15 The env variable file size is 35898 bytes
# >>>   2020/11/19 15:35:15 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# >>>   2020/11/19 15:35:15 Running Docker command: docker run --ulimit memlock=9223372036854775807 --ulimit nofile=262144:262144 --cap-add sys_ptrace --name 3c5f5207-50d3-48df-ae55-c47ad2ab36ea -v /mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts -v /mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs -v /mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared -v /mnt/batch/tasks/workitems/960825bc-8db4-4430-90bb-c72061b50f37/job-1/3c5f5207-50d3-48df-a_710580c2-ea34-4781-b477-d4913e28463f/certs:/mnt/batch/tasks/workitems/960825bc-8db4-4430-90bb-c72061b50f37/job-1/3c5f5207-50d3-48df-a_710580c2-ea34-4781-b477-d4913e28463f/certs -v /mnt/batch/tasks/startup:/mnt/batch/tasks/startup -v /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/mounts/workspaceblobstore/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/azureml_compute_logs:/mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/mounts/workspaceblobstore/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/azureml_compute_logs -v /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea:/mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea -v /mnt/batch/tasks/workitems/960825bc-8db4-4430-90bb-c72061b50f37/job-1/3c5f5207-50d3-48df-a_710580c2-ea34-4781-b477-d4913e28463f/wd:/mnt/batch/tasks/workitems/960825bc-8db4-4430-90bb-c72061b50f37/job-1/3c5f5207-50d3-48df-a_710580c2-ea34-4781-b477-d4913e28463f/wd -v /opt/azureml:/opt/azureml:ro -w /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/wd --expose 23 --env-file /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/config/.batchai.envlist --shm-size 2g -d -it --privileged --net=host 4f065ca9923c4e649f7d27454535e444.azurecr.io/azureml/azureml_43e9380a32931235e3e4e9c47d2444a4
# >>>   2020/11/19 15:35:16 Check if container 3c5f5207-50d3-48df-ae55-c47ad2ab36ea already exist exited with 0,
# >>>
# >>>   2020/11/19 15:35:16 Check if container 3c5f5207-50d3-48df-ae55-c47ad2ab36ea already exist exited with 0,
# >>>
# >>>   2020/11/19 15:35:16 Attempt 1 of http call to https://northeurope.experiments.azureml.net/history/v1.0/private/subscriptions/08265842-251e-450c-8d28-a06ee3f3c611/resourceGroups/DataSandbox/providers/Microsoft.MachineLearningServices/workspaces/ML-2s-sandbox/runs/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/spans
# >>>   2020/11/19 15:35:17 Container ssh is not required for job type.
# >>>   2020/11/19 15:35:17 Starting docker container succeeded.
# >>>   2020/11/19 15:35:17 Starting docker container succeeded.
# >>>   2020/11/19 15:35:17 runSpecialJobTask: os.GetEnv constants.StdouterrDir: /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/mounts/workspaceblobstore/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/azureml_compute_logs
# >>>   2020/11/19 15:35:17 runSpecialJobTask: Raw cmd for preparation is passed is: /azureml-envs/azureml_a8ca70d65d2e3c18017ee3492bf5c464/bin/python /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/mounts/workspaceblobstore/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"a5e3e774-0434-4491-b848-1debdf6413c3","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2020/11/19 15:35:17 runSpecialJobTask: stdout path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/mounts/workspaceblobstore/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/azureml_compute_logs/65_job_prep-tvmps_bb32c84b0f6820ee92ce0bad528bd58853b1776800a68b6091f7d3b1f951f533_d.txt
# >>>   2020/11/19 15:35:17 runSpecialJobTask: stderr path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/mounts/workspaceblobstore/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/azureml_compute_logs/65_job_prep-tvmps_bb32c84b0f6820ee92ce0bad528bd58853b1776800a68b6091f7d3b1f951f533_d.txt
# >>>   2020/11/19 15:35:17 native cmd: cd /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/mounts/workspaceblobstore/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea;/azureml-envs/azureml_a8ca70d65d2e3c18017ee3492bf5c464/bin/python /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/mounts/workspaceblobstore/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"a5e3e774-0434-4491-b848-1debdf6413c3","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2020/11/19 15:35:18 runSpecialJobTask: commons.GetOsPlatform(): ubuntu
# >>>   2020/11/19 15:35:18 runSpecialJobTask: Running cmd: /usr/bin/docker exec -t 3c5f5207-50d3-48df-ae55-c47ad2ab36ea bash -c if [ -f ~/.bashrc ]; then PS1_back=$PS1; PS1='$'; . ~/.bashrc; PS1=$PS1_back; fi;PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;cd /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/mounts/workspaceblobstore/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea;/azureml-envs/azureml_a8ca70d65d2e3c18017ee3492bf5c464/bin/python /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/mounts/workspaceblobstore/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"a5e3e774-0434-4491-b848-1debdf6413c3","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2020/11/19 15:35:22 runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2020/11/19 15:35:22 runSpecialJobTask: preparation: [2020-11-19T15:35:19.176290] Entering job preparation.
# >>>   2020/11/19 15:35:22 runSpecialJobTask: preparation: [2020-11-19T15:35:19.854697] Starting job preparation.
# >>>   2020/11/19 15:35:22 runSpecialJobTask: preparation: [2020-11-19T15:35:19.854736] Extracting the control code.
# >>>   2020/11/19 15:35:22 runSpecialJobTask: preparation: [2020-11-19T15:35:19.876391] fetching and extracting the control code on master node.
# >>>   2020/11/19 15:35:22 runSpecialJobTask: preparation: [2020-11-19T15:35:19.876440] Starting extract_project.
# >>>   2020/11/19 15:35:22 runSpecialJobTask: preparation: [2020-11-19T15:35:19.876555] Starting to extract zip file.
# >>>   2020/11/19 15:35:22 runSpecialJobTask: preparation: [2020-11-19T15:35:20.573199] Finished extracting zip file.
# >>>   2020/11/19 15:35:22 runSpecialJobTask: preparation: [2020-11-19T15:35:20.716256] Using urllib.request Python 3.0 or later
# >>>   2020/11/19 15:35:22 runSpecialJobTask: preparation: [2020-11-19T15:35:20.716314] Start fetching snapshots.
# >>>   2020/11/19 15:35:22 runSpecialJobTask: preparation: [2020-11-19T15:35:20.716354] Start fetching snapshot.
# >>>   2020/11/19 15:35:22 runSpecialJobTask: preparation: [2020-11-19T15:35:20.716369] Retrieving project from snapshot: a5e3e774-0434-4491-b848-1debdf6413c3
# >>>   2020/11/19 15:35:22 runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 48
# >>>   2020/11/19 15:35:22 runSpecialJobTask: preparation: [2020-11-19T15:35:21.306662] Finished fetching snapshot.
# >>>   2020/11/19 15:35:22 runSpecialJobTask: preparation: [2020-11-19T15:35:21.306722] Finished fetching snapshots.
# >>>   2020/11/19 15:35:22 runSpecialJobTask: preparation: [2020-11-19T15:35:21.306786] Finished extract_project.
# >>>   2020/11/19 15:35:22 runSpecialJobTask: preparation: [2020-11-19T15:35:21.320284] Finished fetching and extracting the control code.
# >>>   2020/11/19 15:35:22 runSpecialJobTask: preparation: [2020-11-19T15:35:21.324155] Start run_history_prep.
# >>>   2020/11/19 15:35:22 runSpecialJobTask: preparation: [2020-11-19T15:35:21.324241] downloadDataStore - Download from datastores if requested.
# >>>   2020/11/19 15:35:22 runSpecialJobTask: preparation: [2020-11-19T15:35:21.372013] Entering context manager injector.
# >>>   2020/11/19 15:35:22 runSpecialJobTask: preparation: Acquired lockfile /tmp/3c5f5207-50d3-48df-ae55-c47ad2ab36ea-datastore.lock to downloading input data references
# >>>   2020/11/19 15:35:22 runSpecialJobTask: preparation: [2020-11-19T15:35:22.682776] downloadDataStore completed
# >>>   2020/11/19 15:35:22 runSpecialJobTask: preparation: [2020-11-19T15:35:22.686110] Job preparation is complete.
# >>>   2020/11/19 15:35:23 All App Insights Logs was send successfully
# >>>   2020/11/19 15:35:23 Process Exiting with Code:  0
# >>>
# 2020-11-19T15:35:23Z 127.0.0.1 slots=2 max-slots=2
# 2020-11-19T15:35:23Z launching Custom job
# 2020-11-19T15:35:37Z job exited with code 0
# 2020-11-19T15:35:37Z Executing 'JobRelease task' on 10.0.0.8
# 2020-11-19T15:35:40Z JobRelease task succeeded on 10.0.0.8. Output:
# >>>   2020/11/19 15:35:37 Starting App Insight Logger for task:  jobRelease
# >>>   2020/11/19 15:35:37 Version: 3.0.01405.0001 Branch: .SourceBranch Commit: a9557e7
# >>>   2020/11/19 15:35:37 runSpecialJobTask: os.GetEnv constants.StdouterrDir: /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/mounts/workspaceblobstore/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/azureml_compute_logs
# >>>   2020/11/19 15:35:37 runSpecialJobTask: Raw cmd for postprocessing is passed is: export AZ_BATCHAI_RUN_STATUS='SUCCEEDED';export AZ_BATCHAI_LOG_UPLOAD_FAILED='false';/azureml-envs/azureml_a8ca70d65d2e3c18017ee3492bf5c464/bin/python $AZ_BATCHAI_JOB_MOUNT_ROOT/workspaceblobstore/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/azureml-setup/job_release.py -i DataStoreCopy:context_managers.DataStores
# >>>   2020/11/19 15:35:37 runSpecialJobTask: stdout path for postprocessing is passed is: /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/mounts/workspaceblobstore/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/azureml_compute_logs/75_job_post-tvmps_bb32c84b0f6820ee92ce0bad528bd58853b1776800a68b6091f7d3b1f951f533_d.txt
# >>>   2020/11/19 15:35:37 runSpecialJobTask: stderr path for postprocessing is passed is: /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/mounts/workspaceblobstore/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/azureml_compute_logs/75_job_post-tvmps_bb32c84b0f6820ee92ce0bad528bd58853b1776800a68b6091f7d3b1f951f533_d.txt
# >>>   2020/11/19 15:35:37 native cmd: cd /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/mounts/workspaceblobstore/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea;export AZ_BATCHAI_RUN_STATUS='SUCCEEDED';export AZ_BATCHAI_LOG_UPLOAD_FAILED='false';/azureml-envs/azureml_a8ca70d65d2e3c18017ee3492bf5c464/bin/python $AZ_BATCHAI_JOB_MOUNT_ROOT/workspaceblobstore/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/azureml-setup/job_release.py -i DataStoreCopy:context_managers.DataStores
# >>>   2020/11/19 15:35:37 runSpecialJobTask: commons.GetOsPlatform(): ubuntu
# >>>   2020/11/19 15:35:37 runSpecialJobTask: Running cmd: /usr/bin/docker exec -t 3c5f5207-50d3-48df-ae55-c47ad2ab36ea bash -c if [ -f ~/.bashrc ]; then PS1_back=$PS1; PS1='$'; . ~/.bashrc; PS1=$PS1_back; fi;PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;cd /mnt/batch/tasks/shared/LS_root/jobs/ml-2s-sandbox/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/mounts/workspaceblobstore/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea;export AZ_BATCHAI_RUN_STATUS='SUCCEEDED';export AZ_BATCHAI_LOG_UPLOAD_FAILED='false';/azureml-envs/azureml_a8ca70d65d2e3c18017ee3492bf5c464/bin/python $AZ_BATCHAI_JOB_MOUNT_ROOT/workspaceblobstore/azureml/3c5f5207-50d3-48df-ae55-c47ad2ab36ea/azureml-setup/job_release.py -i DataStoreCopy:context_managers.DataStores
# >>>   2020/11/19 15:35:40 runSpecialJobTask: job postprocessing exited with code 0 and err <nil>
# >>>
# >>>   2020/11/19 15:35:40 runSpecialJobTask: postprocessing: [2020-11-19T15:35:37.977831] Entering job release
# >>>   2020/11/19 15:35:40 runSpecialJobTask: postprocessing: [2020-11-19T15:35:39.036165] Starting job release
# >>>   2020/11/19 15:35:40 runSpecialJobTask: postprocessing: [2020-11-19T15:35:39.041091] Logging experiment finalizing status in history service.
# >>>   2020/11/19 15:35:40 runSpecialJobTask: postprocessing: Starting the daemon thread to refresh tokens in background for process with pid = 151
# >>>   2020/11/19 15:35:40 runSpecialJobTask: postprocessing: [2020-11-19T15:35:39.056279] job release stage : upload_datastore starting...
# >>>   2020/11/19 15:35:40 runSpecialJobTask: postprocessing: [2020-11-19T15:35:39.056983] job release stage : start importing azureml.history._tracking in run_history_release.
# >>>   2020/11/19 15:35:40 runSpecialJobTask: postprocessing: [2020-11-19T15:35:39.057160] job release stage : copy_batchai_cached_logs starting...
# >>>   2020/11/19 15:35:40 runSpecialJobTask: postprocessing: [2020-11-19T15:35:39.057244] job release stage : execute_job_release starting...
# >>>   2020/11/19 15:35:40 runSpecialJobTask: postprocessing: [2020-11-19T15:35:39.059067] job release stage : copy_batchai_cached_logs completed...
# >>>   2020/11/19 15:35:40 runSpecialJobTask: postprocessing: [2020-11-19T15:35:39.059478] Entering context manager injector.
# >>>   2020/11/19 15:35:40 runSpecialJobTask: postprocessing: [2020-11-19T15:35:39.293582] job release stage : upload_datastore completed...
# >>>   2020/11/19 15:35:40 runSpecialJobTask: postprocessing: [2020-11-19T15:35:39.322617] job release stage : send_run_telemetry starting...
# >>>   2020/11/19 15:35:40 runSpecialJobTask: postprocessing: [2020-11-19T15:35:39.515500] job release stage : execute_job_release completed...
# >>>   2020/11/19 15:35:40 runSpecialJobTask: postprocessing: [2020-11-19T15:35:40.507946] job release stage : send_run_telemetry completed...
# >>>   2020/11/19 15:35:40 runSpecialJobTask: postprocessing: [2020-11-19T15:35:40.508264] Job release is complete
# >>>   2020/11/19 15:35:40 All App Insights Logs was send successfully
# >>>
# 2020-11-19T15:35:41Z Executing 'Job environment clean-up' on 10.0.0.8
# 2020-11-19T15:35:41Z Removing container 3c5f5207-50d3-48df-ae55-c47ad2ab36ea exited with 0, 3c5f5207-50d3-48df-ae55-c47ad2ab36ea
#
#
#
# Streaming azureml-logs/75_job_post-tvmps_bb32c84b0f6820ee92ce0bad528bd58853b1776800a68b6091f7d3b1f951f533_d.txt
# ===============================================================================================================
# [2020-11-19T15:35:37.977831] Entering job release
# [2020-11-19T15:35:39.036165] Starting job release
# [2020-11-19T15:35:39.041091] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 151
# [2020-11-19T15:35:39.056279] job release stage : upload_datastore starting...
# [2020-11-19T15:35:39.056983] job release stage : start importing azureml.history._tracking in run_history_release.
# [2020-11-19T15:35:39.057160] job release stage : copy_batchai_cached_logs starting...
# [2020-11-19T15:35:39.057244] job release stage : execute_job_release starting...
# [2020-11-19T15:35:39.059067] job release stage : copy_batchai_cached_logs completed...
# [2020-11-19T15:35:39.059478] Entering context manager injector.
# [2020-11-19T15:35:39.293582] job release stage : upload_datastore completed...
# [2020-11-19T15:35:39.322617] job release stage : send_run_telemetry starting...
# [2020-11-19T15:35:39.515500] job release stage : execute_job_release completed...
# [2020-11-19T15:35:40.507946] job release stage : send_run_telemetry completed...
# [2020-11-19T15:35:40.508264] Job release is complete
#
# StepRun(train model) Execution Summary
# =======================================
# StepRun( train model ) Status: Finished
# {'runId': '3c5f5207-50d3-48df-ae55-c47ad2ab36ea', 'target': 'DS-Ass-Cluster', 'status': 'Completed', 'startTimeUtc': '2020-11-19T15:35:12.324561Z', 'endTimeUtc': '2020-11-19T15:35:47.486964Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': 'a5e3e774-0434-4491-b848-1debdf6413c3', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': 'fec89449-8b51-4478-93a7-dca54c311451', 'azureml.nodeid': 'c7b16640', 'azureml.pipelinerunid': '3ff91f37-a11d-4d57-a9c5-df44797d7b90', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [], 'runDefinition': {'script': 'diabetes_experiment.py', 'useAbsolutePath': False, 'arguments': ['--input-folder', '$AZUREML_DATAREFERENCE_prepped_data'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'DS-Ass-Cluster', 'dataReferences': {'prepped_data': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/f9a75782-f51a-43c1-a237-b5bb3c504167/prepped_data', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'priority': None, 'environment': {'name': 'Experiment diabetes-test-pipeline Environment', 'version': 'Autosave_2020-11-19T15:18:21Z_9cd0bbc6', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults', 'azureml-dataprep[pandas]']}, 'scikit-learn', 'matplotlib'], 'name': 'azureml_a8ca70d65d2e3c18017ee3492bf5c464'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20200821.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': False}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'frameworkImage': None, 'imageVersion': None, 'location': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': True, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}}, 'logFiles': {'azureml-logs/55_azureml-execution-tvmps_bb32c84b0f6820ee92ce0bad528bd58853b1776800a68b6091f7d3b1f951f533_d.txt': 'https://ml2ssandbox5194139173.blob.core.windows.net/azureml/ExperimentRun/dcid.3c5f5207-50d3-48df-ae55-c47ad2ab36ea/azureml-logs/55_azureml-execution-tvmps_bb32c84b0f6820ee92ce0bad528bd58853b1776800a68b6091f7d3b1f951f533_d.txt?sv=2019-02-02&sr=b&sig=FBU9uuW0q%2FarTX0LHmY3LLNY68FUpZFX6m04R5YP9mc%3D&st=2020-11-19T15%3A25%3A43Z&se=2020-11-19T23%3A35%3A43Z&sp=r', 'azureml-logs/65_job_prep-tvmps_bb32c84b0f6820ee92ce0bad528bd58853b1776800a68b6091f7d3b1f951f533_d.txt': 'https://ml2ssandbox5194139173.blob.core.windows.net/azureml/ExperimentRun/dcid.3c5f5207-50d3-48df-ae55-c47ad2ab36ea/azureml-logs/65_job_prep-tvmps_bb32c84b0f6820ee92ce0bad528bd58853b1776800a68b6091f7d3b1f951f533_d.txt?sv=2019-02-02&sr=b&sig=CLGAmeOQJPQdvz6 ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '3ff91f37-a11d-4d57-a9c5-df44797d7b90', 'status': 'Completed', 'startTimeUtc': '2020-11-19T15:33:43.816476Z', 'endTimeUtc': '2020-11-19T15:35:55.424958Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://ml2ssandbox5194139173.blob.core.windows.net/azureml/ExperimentRun/dcid.3ff91f37-a11d-4d57-a9c5-df44797d7b90/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=RlciQFXXoTOA1g4uxfrLELielOdaTML%2B2o%2FAqqMFLfM%3D&st=2020-11-19T15%3A25%3A58Z&se=2020-11-19T23%3A35%3A58Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://ml2ssandbox5194139173.blob.core.windows.net/azureml/ExperimentRun/dcid.3ff91f37-a11d-4d57-a9c5-df44797d7b90/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=boKiA1VCNODyzvVdI2TQPV2QoBubk0EWKafA1i94RDE%3D&st=2020-11-19T15%3A25%3A58Z&se=2020-11-19T23%3A35%3A58Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://ml2ssandbox5194139173.blob.core.windows.net/azureml/ExperimentRun/dcid.3ff91f37-a11d-4d57-a9c5-df44797d7b90/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=nhCfN6%2FKWerkPlKqQPdv4O0oNmlHibIeSYE%2BgAKkzOs%3D&st=2020-11-19T15%3A25%3A58Z&se=2020-11-19T23%3A35%3A58Z&sp=r'}}
# 'Finished'

# %%
pipeline_run
# Out:
# Run(Experiment: diabetes-test-pipeline,
# Id: 3ff91f37-a11d-4d57-a9c5-df44797d7b90,
# Type: azureml.PipelineRun,
# Status: Completed)
